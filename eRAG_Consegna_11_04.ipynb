# %% [markdown]
# # eRAG: Evaluating Retrieval Quality in Retrieval-Augmented Generation
#
# This notebook is an attempt to reproduce the core pipeline used to obtain the results in the paper titled "[Evaluating Retrieval Quality in Retrieval-Augmented Generation](https://arxiv.org/abs/2404.13781)."

# %% [markdown]
# ## Downloading the NQ dataset

# %%
# Create a directory for data if it doesn't exist
# !mkdir -p data

# Download the NQ dataset (e.g., the dev file)
# !wget -O data/nq-dev-kilt.jsonl http://dl.fbaipublicfiles.com/KILT/nq-dev-kilt.jsonl
# !wget -O data/nq-train-kilt.jsonl http://dl.fbaipublicfiles.com/KILT/nq-train-kilt.jsonl
# !wget -O data/nq-test_without_answers-kilt.jsonl http://dl.fbaipublicfiles.com/KILT/nq-test_without_answers-kilt.jsonl
#!wget -O data/fever-dev-kilt.jsonl http://dl.fbaipublicfiles.com/KILT/fever-dev-kilt.jsonl


# Display a few lines of the file to verify the download
# !head -n 5 data/nq-dev-kilt.jsonl
# !head -n 5 data/nq-train-kilt.jsonl
# !head -n 5 data/nq-test_without_answers-kilt.jsonl
#!head -n 5 data/fever-dev-kilt.jsonl
# Out:
# --2025-04-01 14:41:25--  http://dl.fbaipublicfiles.com/KILT/nq-dev-kilt.jsonl
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 108.157.254.15, 108.157.254.102, 108.157.254.124, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|108.157.254.15|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7936566 (7.6M) [text/plain]
# Saving to: ‘data/nq-dev-kilt.jsonl’
#
# data/nq-dev-kilt.js 100%[===================>]   7.57M  --.-KB/s    in 0.06s
#
# 2025-04-01 14:41:25 (135 MB/s) - ‘data/nq-dev-kilt.jsonl’ saved [7936566/7936566]
#
# --2025-04-01 14:41:25--  http://dl.fbaipublicfiles.com/KILT/nq-train-kilt.jsonl
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 108.157.254.15, 108.157.254.102, 108.157.254.124, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|108.157.254.15|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51895886 (49M) [text/plain]
# Saving to: ‘data/nq-train-kilt.jsonl’
#
# data/nq-train-kilt. 100%[===================>]  49.49M   213MB/s    in 0.2s
#
# 2025-04-01 14:41:26 (213 MB/s) - ‘data/nq-train-kilt.jsonl’ saved [51895886/51895886]
#
# --2025-04-01 14:41:26--  http://dl.fbaipublicfiles.com/KILT/nq-test_without_answers-kilt.jsonl
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 108.157.254.15, 108.157.254.102, 108.157.254.124, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|108.157.254.15|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 334047 (326K) [text/plain]
# Saving to: ‘data/nq-test_without_answers-kilt.jsonl’
#
# data/nq-test_withou 100%[===================>] 326.22K  --.-KB/s    in 0.007s
#
# 2025-04-01 14:41:26 (43.8 MB/s) - ‘data/nq-test_without_answers-kilt.jsonl’ saved [334047/334047]
#
# {"id": "6915606477668963399", "input": "what do the 3 dots mean in math", "output": [{"answer": "the therefore sign", "provenance": [{"wikipedia_id": "10593264", "title": "Therefore sign", "start_paragraph_id": 1, "start_character": 44, "end_paragraph_id": 1, "end_character": 62, "bleu_score": 1.0, "section": "Section::::Abstract."}]}, {"answer": "therefore sign", "provenance": [{"wikipedia_id": "10593264", "title": "Therefore sign", "start_paragraph_id": 1, "start_character": 48, "end_paragraph_id": 1, "end_character": 62, "bleu_score": 1.0, "section": "Section::::Abstract."}]}, {"answer": "a logical consequence , such as the conclusion of a syllogism"}, {"answer": "the therefore sign ( \u2234 ) is generally used before a logical consequence , such as the conclusion of a syllogism"}, {"provenance": [{"wikipedia_id": "10593264", "title": "Therefore sign", "start_paragraph_id": 1, "start_character": 0, "end_paragraph_id": 1, "end_character": 375, "bleu_score": 0.6816476074249925, "meta": {"yes_no_answer": "NONE", "annotation_id": 13591449469826568799}, "section": "Section::::Abstract."}]}, {"provenance": [{"wikipedia_id": "10593264", "title": "Therefore sign", "section": "Section::::Abstract.", "start_paragraph_id": 1, "end_paragraph_id": 1, "meta": {"evidence_span": ["The symbol consists of three dots placed in an upright triangle and is read \"therefore\".", "The symbol consists of three dots placed in an upright triangle and is read \"therefore\".", "The symbol consists of three dots placed in an upright triangle and is read \"therefore\".", "In logical argument and mathematical proof, the therefore sign () is generally used before a logical consequence, such as the conclusion of a syllogism. The symbol consists of three dots placed in an upright triangle and is read \"therefore\". It is encoded at ."]}}]}]}
# {"id": "-8366545547296627039", "input": "who wrote the song photograph by ringo starr", "output": [{"answer": "Ringo Starr", "provenance": [{"wikipedia_id": "2448355", "title": "Photograph (Ringo Starr song)", "start_paragraph_id": 0, "start_character": 12, "end_paragraph_id": 0, "end_character": 23, "bleu_score": 1.0, "section": "Section::::Abstract."}]}, {"answer": "George Harrison", "provenance": [{"wikipedia_id": "2448355", "title": "Photograph (Ringo Starr song)", "start_paragraph_id": 1, "start_character": 150, "end_paragraph_id": 1, "end_character": 165, "bleu_score": 1.0, "section": "Section::::Abstract."}]}, {"answer": "Richard Starkey"}, {"provenance": [{"wikipedia_id": "2448355", "title": "Photograph (Ringo Starr song)", "start_paragraph_id": 1, "start_character": 0, "end_paragraph_id": 1, "end_character": 714, "bleu_score": 0.9400346272745647, "meta": {"yes_no_answer": "NONE", "annotation_id": 647276088892962831}, "section": "Section::::Abstract."}]}, {"provenance": [{"wikipedia_id": "2448355", "title": "Photograph (Ringo Starr song)", "section": "Section::::Background and composition.\n", "start_paragraph_id": 6, "end_paragraph_id": 6, "meta": {"evidence_span": ["As with Starr's two singles over 197172, \"It Don't Come Easy\" and \"Back Off Boogaloo\", Harrison helped write the melody, although \"Photograph\" marked the first time that he was credited as a co-writer with Starr.", "Harrison helped write the melody, although \"Photograph\" marked the first time that he was credited as a co-writer with Starr.", "Another guest on the \"Marala\" was Cilla Black, singer and a friend to the Beatles since the 1960s, who recalls Starr and Harrison playing \"Photograph\" during an evening get-together, with \"everyone on board\" contributing ideas for the lyrics. As with Starr's two singles over 197172, \"It Don't Come Easy\" and \"Back Off Boogaloo\", Harrison helped write the melody, although \"Photograph\" marked the first time that he was credited as a co-writer with Starr."]}}]}, {"provenance": [{"wikipedia_id": "2448355", "title": "Photograph (Ringo Starr song)", "section": "Section::::Abstract.", "start_paragraph_id": 1, "end_paragraph_id": 1, "meta": {"evidence_span": ["\"Photograph\" is a song by English musician Ringo Starr that was released as the lead single from his 1973 album \"Ringo\"", "\"Photograph\" is a song by English musician Ringo Starr that was released as the lead single from his 1973 album \"Ringo\". Starr co-wrote the song with George Harrison,", "\"Photograph\" is a song by English musician Ringo Starr that was released as the lead single from his 1973 album \"Ringo\". Starr co-wrote the song with George Harrison, his former bandmate from the Beatles.", "\"Photograph\" is a song by English musician Ringo Starr that was released as the lead single from his 1973 album \"Ringo\". Starr co-wrote the song with George Harrison"]}}]}]}
# {"id": "-5004457603684974952", "input": "who is playing the halftime show at super bowl 2016", "output": [{"answer": "Coldplay", "provenance": [{"wikipedia_id": "45267196", "title": "Super Bowl 50 halftime show", "start_paragraph_id": 1, "start_character": 178, "end_paragraph_id": 1, "end_character": 186, "bleu_score": 1.0, "section": "Section::::Abstract."}]}, {"answer": "Beyonc\u00e9", "provenance": [{"wikipedia_id": "45267196", "title": "Super Bowl 50 halftime show", "start_paragraph_id": 1, "start_character": 217, "end_paragraph_id": 1, "end_character": 224, "bleu_score": 1.0, "section": "Section::::Abstract."}]}, {"answer": "Bruno Mars", "provenance": [{"wikipedia_id": "45267196", "title": "Super Bowl 50 halftime show", "start_paragraph_id": 1, "start_character": 229, "end_paragraph_id": 1, "end_character": 239, "bleu_score": 1.0, "section": "Section::::Abstract."}]}, {"answer": "Coldplay with special guest performers Beyonc\u00e9 and Bruno Mars"}, {"answer": "British rock group Coldplay with special guest performers Beyonc\u00e9 and Bruno Mars"}, {"provenance": [{"wikipedia_id": "45267196", "title": "Super Bowl 50 halftime show", "start_paragraph_id": 1, "start_character": 0, "end_paragraph_id": 1, "end_character": 341, "bleu_score": 0.9657992495762466, "meta": {"yes_no_answer": "NONE", "annotation_id": 2430977867500315580}, "section": "Section::::Abstract."}]}, {"provenance": [{"wikipedia_id": "45267196", "title": "Super Bowl 50 halftime show", "section": "Section::::Abstract.", "start_paragraph_id": 1, "end_paragraph_id": 1, "meta": {"evidence_span": ["It was headlined by the British rock group Coldplay with special guest performers Beyonc\u00e9 and Bruno Mars", "It was headlined by the British rock group Coldplay with special guest performers Beyonc\u00e9 and Bruno Mars, who previously had headlined the Super Bowl XLVII and Super Bowl XLVIII halftime shows, respectively.", "The Super Bowl 50 Halftime Show took place on February 7, 2016, at Levi's Stadium in Santa Clara, California as part of Super Bowl 50. It was headlined by the British rock group Coldplay with special guest performers Beyonc\u00e9 and Bruno Mars", "The Super Bowl 50 Halftime Show took place on February 7, 2016, at Levi's Stadium in Santa Clara, California as part of Super Bowl 50. It was headlined by the British rock group Coldplay with special guest performers Beyonc\u00e9 and Bruno Mars,"]}}]}]}
# {"id": "7217222058435937287", "input": "where was the world economic forum held this year", "output": [{"answer": "Davos", "provenance": [{"wikipedia_id": "172185", "title": "World Economic Forum", "start_paragraph_id": 2, "start_character": 57, "end_paragraph_id": 2, "end_character": 62, "bleu_score": 1.0, "section": "Section::::Abstract."}]}, {"answer": "Davos , a mountain resort in Graub\u00fcnden , in the eastern Alps region of Switzerland"}, {"provenance": [{"wikipedia_id": "172185", "title": "World Economic Forum", "start_paragraph_id": 12, "start_character": 0, "end_paragraph_id": 12, "end_character": 348, "bleu_score": 0.9632870032952194, "meta": {"yes_no_answer": "NONE", "annotation_id": 14014754538899837203}, "section": "Section::::History.\n"}]}, {"provenance": [{"wikipedia_id": "172185", "title": "World Economic Forum", "section": "Section::::Abstract.", "start_paragraph_id": 2, "end_paragraph_id": 2, "meta": {"evidence_span": ["The WEF hosts an annual meeting at the end of January in Davos, a mountain resort in Graub\u00fcnden, in the eastern Alps region of Switzerland", "The WEF hosts an annual meeting at the end of January in Davos, a mountain resort in Graub\u00fcnden, in the eastern Alps region of Switzerland.", "The WEF hosts an annual meeting at the end of January in Davos, a mountain resort in Graub\u00fcnden, in the eastern Alps region of Switzerland.", "The WEF hosts an annual meeting at the end of January in Davos, a mountain resort in Graub\u00fcnden, in the eastern Alps region of Switzerland"]}}]}, {"provenance": [{"wikipedia_id": "40628105", "title": "World Social Forum", "section": "Section::::Abstract.", "start_paragraph_id": 1, "end_paragraph_id": 1, "meta": {"evidence_span": ["It tends to meet in January at the same time as its \"great capitalist rival\", the World Economic Forum's Annual Meeting in Davos, Switzerland.", "It tends to meet in January at the same time as its \"great capitalist rival\", the World Economic Forum's Annual Meeting in Davos, Switzerland.", "the World Economic Forum's Annual Meeting in Davos, Switzerland"]}}]}], "meta": {"partial_evidence": [{"wikipedia_id": "172185", "title": "World Economic Forum", "section": "Section::::History.\n", "start_paragraph_id": 13, "end_paragraph_id": 13, "meta": {"evidence_span": ["On his first international trip to Davos, he emphasized liberal economic policies despite his populist agenda, and attempted to reassure the world that Brazil is a protector of the rain forest while utilizing its resources for food production and export", "On his first international trip to Davos", ". In 2019, Brazilian President Jair Bolsonaro gave the keynote address at the plenary session of the conference. On his first international trip to Davos,"]}}]}}
# {"id": "-143054837169120955", "input": "where are the giant redwoods located in california", "output": [{"answer": "Humboldt County", "provenance": [{"wikipedia_id": "758737", "title": "Redwood National and State Parks", "start_paragraph_id": 9, "start_character": 172, "end_paragraph_id": 9, "end_character": 187, "bleu_score": 1.0, "section": "Section::::History.\n"}]}, {"answer": "the coast of northern California", "provenance": [{"wikipedia_id": "758737", "title": "Redwood National and State Parks", "start_paragraph_id": 1, "start_character": 130, "end_paragraph_id": 1, "end_character": 162, "bleu_score": 1.0, "section": "Section::::Abstract."}]}, {"answer": "from the northern California coast north to the southern Oregon Coast"}, {"answer": "Del Norte County"}, {"provenance": [{"wikipedia_id": "758737", "title": "Redwood National and State Parks", "start_paragraph_id": 0, "start_character": 0, "end_paragraph_id": 0, "end_character": 0, "bleu_score": 1.0, "meta": {"yes_no_answer": "NONE", "annotation_id": 16665979442690208418}, "section": "Section::::Abstract."}]}, {"provenance": [{"wikipedia_id": "758737", "title": "Redwood National and State Parks", "start_paragraph_id": 18, "start_character": 0, "end_paragraph_id": 18, "end_character": 450, "bleu_score": 0.8094520197344047, "meta": {"yes_no_answer": "NONE", "annotation_id": 16665979442690208418}, "section": "Section::::Natural resources.:Flora.\n"}]}, {"provenance": [{"wikipedia_id": "758737", "title": "Redwood National and State Parks", "start_paragraph_id": 1, "start_character": 0, "end_paragraph_id": 1, "end_character": 862, "bleu_score": 0.8696358546713313, "meta": {"yes_no_answer": "NONE", "annotation_id": 16665979442690208418}, "section": "Section::::Abstract."}]}, {"provenance": [{"wikipedia_id": "5047618", "title": "Redwood Mountain Grove", "section": "Section::::Abstract.", "start_paragraph_id": 1, "end_paragraph_id": 1, "meta": {"evidence_span": ["It is located in Kings Canyon National Park and Giant Sequoia National Monument on the western slope of California's Sierra Nevada.", "Redwood Mountain Grove is the largest grove of giant sequoia (\"Sequoiadendron giganteum\") trees on earth. It is located in Kings Canyon National Park and Giant Sequoia National Monument on the western slope of California's Sierra Nevada.", "Redwood Mountain Grove is the largest grove of giant sequoia (\"Sequoiadendron giganteum\") trees on earth. It is located in Kings Canyon National Park and Giant Sequoia National Monument on the western slope of California's Sierra Nevada."]}}]}, {"provenance": [{"wikipedia_id": "50612691", "title": "Redwood Experimental Forest", "section": "Section::::Abstract.", "start_paragraph_id": 1, "end_paragraph_id": 1, "meta": {"evidence_span": ["The forest is near the mouth of the Klamath River in the California Coast Ranges of Northern California.", "The forest is near the mouth of the Klamath River in the California Coast Ranges of Northern California. The forest is drained by High Prairie Creek.", "The Redwood Experimental Forest (also Yurok Redwood Experimental Forest, formerly Yurok Experimental Forest) (established 1940) is an experimental forest in Del Norte County, California. The forest is near the mouth of the Klamath River in the California Coast Ranges of Northern California.", "The Redwood Experimental Forest (also Yurok Redwood Experimental Forest, formerly Yurok Experimental Forest) (established 1940) is an experimental forest in Del Norte County, California. The forest is near the mouth of the Klamath River in the California Coast Ranges of Northern California. The forest is drained by High Prairie Creek. As its name implies, the principal species in the forest is coast redwood (\"Sequoia sempervirens\"), but the site also contains Douglas fir, Sitka spruce, western hemlock, and Port Orford cedar."]}}]}, {"provenance": [{"wikipedia_id": "758737", "title": "Redwood National and State Parks", "section": "Section::::Abstract.", "start_paragra ...
# {"id": "5328212470870865242", "input": "how i.met your mother who is the mother", "output": [{"answer": "Tracy McConnell", "provenance": [{"wikipedia_id": "40262098", "title": "The Mother (How I Met Your Mother)", "start_paragraph_id": 1, "start_character": 0, "end_paragraph_id": 1, "end_character": 15, "bleu_score": 1.0, "section": "Section::::Abstract."}]}, {"provenance": [{"wikipedia_id": "40262098", "title": "The Mother (How I Met Your Mother)", "start_paragraph_id": 1, "start_character": 41, "end_paragraph_id": 1, "end_character": 487, "bleu_score": 0.8409682712135438, "meta": {"yes_no_answer": "NONE", "annotation_id": 12034874153783787365}, "section": "Section::::Abstract."}]}]}
# {"id": "5289242154789678439", "input": "who had the most wins in the nfl", "output": [{"answer": "Tom Brady", "provenance": [{"wikipedia_id": "13929036", "title": "List of National Football League career quarterback wins leaders", "start_paragraph_id": 2, "start_character": 19, "end_paragraph_id": 2, "end_character": 28, "bleu_score": 1.0, "section": "Section::::Abstract."}]}, {"provenance": [{"wikipedia_id": "13929036", "title": "List of National Football League career quarterback wins leaders", "start_paragraph_id": 2, "start_character": 0, "end_paragraph_id": 2, "end_character": 317, "bleu_score": 0.6220878649185788, "meta": {"yes_no_answer": "NONE", "annotation_id": 14634796365152556576}, "section": "Section::::Abstract."}]}]}
# {"id": "-2500044561429484630", "input": "who played mantis guardians of the galaxy 2", "output": [{"answer": "Pom Klementieff", "provenance": [{"wikipedia_id": "43209054", "title": "Pom Klementieff", "start_paragraph_id": 0, "start_character": 0, "end_paragraph_id": 0, "end_character": 15, "bleu_score": 1.0, "section": "Section::::Abstract."}]}, {"provenance": [{"wikipedia_id": "43209054", "title": "Pom Klementieff", "start_paragraph_id": 1, "start_character": 0, "end_paragraph_id": 1, "end_character": 363, "bleu_score": 0.6270481137694314, "meta": {"yes_no_answer": "NONE", "annotation_id": 12644762478285625867}, "section": "Section::::Abstract."}]}]}
# {"id": "-1706790511507651062", "input": "what channel is the premier league on in france", "output": [{"answer": "SFR Sport"}]}
# {"id": "-7491001389340565191", "input": "god's not dead a light in the darkness release date", "output": [{"answer": "March 30 , 2018", "provenance": [{"wikipedia_id": "56095752", "title": "God's Not Dead: A Light in Darkness", "start_paragraph_id": 24, "start_character": 87, "end_paragraph_id": 24, "end_character": 102, "bleu_score": 1.0, "section": "Section::::Reception.:Box office.\n"}]}, {"provenance": [{"wikipedia_id": "56095752", "title": "God's Not Dead: A Light in Darkness", "start_paragraph_id": 2, "start_character": 0, "end_paragraph_id": 2, "end_character": 312, "bleu_score": 0.5704004850604518, "meta": {"yes_no_answer": "NONE", "annotation_id": 7714113395991537822}, "section": "Section::::Abstract."}]}]}
# {"id": "-4203908294749842710", "input": "what is the definition of bcc in email"}
# {"id": "9149758552440472471", "input": "an insured status under social security can be described as"}
# {"id": "-5620495892196990154", "input": "what is it called when a deer sheds its antlers"}
# {"id": "5317988699618286188", "input": "who played the first a star is born"}
# {"id": "3994708788434954529", "input": "when was the notre dame fight song written"}

# %% [markdown]
# ## Wikipedia preprocessing using the KILT source

# %%
import json
import requests
import pdb


# Splits text into passages max_words long
def split_into_passages(text, max_words=100):
    """Splits text into passages of up to max_words words (without overlap)."""
    words = text.split()
    passages = []
    for i in range(0, len(words), max_words):
        chunk = " ".join(words[i:i+max_words])
        passages.append(chunk)
    return passages


# Retrieves title and text of a document, applies split_into_passages, and concatenates
def process_kilt_page(page_json, max_words=100):
    """
    Given a KILT knowledge source page (record),
    segments the "text" field (list of paragraphs) into passages of max_words.
    Returns a list of documents combining the title and passage.
    """
    title = page_json.get("wikipedia_title", "").strip()
    paragraphs = page_json.get("text", [])
    docs = []
    for para in paragraphs:
        para = para.strip()
        if not para:
            continue
        passages = split_into_passages(para, max_words=max_words)
        for p in passages:
            doc = f"{title} [SEP] {p}"
            docs.append(doc)
    return docs


# File paths
input_file = 'kilt_knowledgesource.json'
output_file = 'wikipedia_passages_sample.jsonl'

# Process 1/1000 of all the records for demonstration (the full file is too large: 5903530 records)
num_records_to_process = 5903

url = "http://dl.fbaipublicfiles.com/KILT/kilt_knowledgesource.json"

# Reads the file line by line to avoid the full download
with requests.get(url, stream=True) as r, open(output_file, 'w', encoding='utf-8') as fout:
    for i, line in enumerate(r.iter_lines()):
        if i >= num_records_to_process:
            print("Superato limite")
            break
        try:
            page = json.loads(line)
        except json.JSONDecodeError as e:
            print(f"Error decoding record {i}: {e}")
            continue
        docs = process_kilt_page(page, max_words=100)
        for doc in docs:
            # Save each document as JSON Lines
            json.dump({"document": doc}, fout)
            fout.write("\n")

print(f"Processed {num_records_to_process} records. Output saved in '{output_file}'.")

# Display the first 5 lines of the output file
# !head -n 5 {output_file}
# Out:
# Superato limite
# Processed 5903 records. Output saved in 'wikipedia_passages_sample.jsonl'.
# {"document": "A [SEP] A"}
# {"document": "A [SEP] A (named , plural \"As\", \"A's\", \"a\"s, \"a's\" or \"aes\") is the first letter and the first vowel of the modern English alphabet and the ISO basic Latin alphabet. It is similar to the Ancient Greek letter alpha, from which it derives. The uppercase version consists of the two slanting sides of a triangle, crossed in the middle by a horizontal bar. The lowercase version can be written in two forms: the double-storey a and single-storey \u0251. The latter is commonly used in handwriting and fonts based on it, especially fonts intended to be read by children, and is also"}
# {"document": "A [SEP] found in italic type."}
# {"document": "A [SEP] In the English grammar, \"a\", and its variant \"an\", is an indefinite article."}
# {"document": "A [SEP] Section::::History."}

# %% [markdown]
# ## Index building

# %% [markdown]
# Dopo aver pre-processato i file (da puro testo, i documenti vengono divisi in titolo + testo e vengono accorciati(?)).
# Ora viene svolto l'indicizzazione tramite BM25 (modello lessicale) e Contriever (modello denso) dei documenti pre-processati.

# %% [markdown]
# ### BM25

# %%
# !pip install rank_bm25 nltk

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string
import numpy as np
import json
from rank_bm25 import BM25Okapi
# Out:
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rank_bm25) (2.0.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Installing collected packages: rank_bm25
# Successfully installed rank_bm25-0.2.2

# %%
try:
    stopwords.words('english')
except LookupError:
    print("Downloading NLTK data ('stopwords', 'punkt')...")
    nltk.download('punkt_tab', quiet=True)
    nltk.download('punkt', quiet=True)
    nltk.download('stopwords', quiet=True)

stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()
punctuation_table = str.maketrans('', '', string.punctuation)

# Simple preprocessing removing stop words and using a stemmer
def preprocess_text(text):
    lowered = text.lower()
    no_punct = lowered.translate(punctuation_table)
    tokens = word_tokenize(no_punct)
    filtered_tokens = [word for word in tokens if word not in stop_words and word.isalnum()]
    stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]
    return stemmed_tokens

# Loading the collection documents
documents = []
input_file = "wikipedia_passages_sample.jsonl"
try:
    with open(input_file, "r", encoding="utf-8") as fin:
        for i, line in enumerate(fin):
            try:
                data = json.loads(line)
                documents.append(data["document"])
            except json.JSONDecodeError:
                print(f"Warning: Skipping invalid JSON on line {i+1}")
except FileNotFoundError:
    print(f"Error: Input file '{input_file}' not found.")
    exit()

if not documents:
    print("No documents loaded. Exiting.")
    exit()


print("Preprocessing documents...")
tokenized_docs = [preprocess_text(doc) for doc in documents]
print(f"Sample preprocessed doc: {tokenized_docs[0:10][:20] if tokenized_docs else 'N/A'}")

print("Building BM25 index...")
bm25 = BM25Okapi(tokenized_docs)

def bm25_retrieve(query, bm25_index, original_docs, k=5):
    # Apply the same preprocessing to the query
    tokenized_query = preprocess_text(query)
    if not tokenized_query:
        print("Warning: Query resulted in empty tokens after preprocessing.")
        return [], [], []

    scores = bm25_index.get_scores(tokenized_query)

    top_n_indices = np.argsort(scores)[::-1][:k]

    top_docs = [original_docs[i] for i in top_n_indices]
    top_scores = [scores[i] for i in top_n_indices]

    return top_n_indices, top_docs, top_scores
# Out:
# Downloading NLTK data ('stopwords', 'punkt')...
# Preprocessing documents...
# Sample preprocessed doc: [['sep'], ['sep', 'name', 'plural', 'ae', 'first', 'letter', 'first', 'vowel', 'modern', 'english', 'alphabet', 'iso', 'basic', 'latin', 'alphabet', 'similar', 'ancient', 'greek', 'letter', 'alpha', 'deriv', 'uppercas', 'version', 'consist', 'two', 'slant', 'side', 'triangl', 'cross', 'middl', 'horizont', 'bar', 'lowercas', 'version', 'written', 'two', 'form', 'doublestorey', 'singlestorey', 'ɑ', 'latter', 'commonli', 'use', 'handwrit', 'font', 'base', 'especi', 'font', 'intend', 'read', 'children', 'also'], ['sep', 'found', 'ital', 'type'], ['sep', 'english', 'grammar', 'variant', 'indefinit', 'articl'], ['sep', 'sectionhistori'], ['sep', 'earliest', 'certain', 'ancestor', 'aleph', 'also', 'written', 'aleph', 'first', 'letter', 'phoenician', 'alphabet', 'consist', 'entir', 'conson', 'reason', 'also', 'call', 'abjad', 'distinguish', 'true', 'alphabet', 'turn', 'ancestor', 'aleph', 'may', 'pictogram', 'ox', 'head', 'protosinait', 'script', 'influenc', 'egyptian', 'hieroglyph', 'style', 'triangular', 'head', 'two', 'horn', 'extend'], ['sep', '1600', 'bc', 'phoenician', 'alphabet', 'letter', 'linear', 'form', 'serv', 'base', 'later', 'form', 'name', 'thought', 'correspond', 'close', 'paleohebrew', 'arab', 'aleph'], ['sep', 'ancient', 'greek', 'adopt', 'alphabet', 'use', 'letter', 'repres', 'glottal', 'conson', 'sound', 'letter', 'denot', 'phoenician', 'semit', 'languag', 'first', 'phonem', 'phoenician', 'pronunci', 'use', 'version', 'sign', 'repres', 'vowel', 'call', 'similar', 'name', 'alpha', 'earliest', 'greek', 'inscript', 'greek', 'dark', 'age', 'date', '8th', 'centuri', 'bc', 'letter', 'rest', 'upon', 'side', 'greek', 'alphabet', 'later', 'time', 'gener', 'resembl', 'modern'], ['sep', 'capit', 'letter', 'although', 'mani', 'local', 'varieti', 'distinguish', 'shorten', 'one', 'leg', 'angl', 'cross', 'line', 'set'], ['sep', 'etruscan', 'brought', 'greek', 'alphabet', 'civil', 'italian', 'peninsula', 'left', 'letter', 'unchang', 'roman', 'later', 'adopt', 'etruscan', 'alphabet', 'write', 'latin', 'languag', 'result', 'letter', 'preserv', 'latin', 'alphabet', 'would', 'come', 'use', 'write', 'mani', 'languag', 'includ', 'english']]
# Building BM25 index...

# %%
# BM25 example usage
query = "gravitational time dilation"
print(f"\nSearching for: '{query}'")
indices, docs_retrieved, scores_retrieved = bm25_retrieve(query, bm25, documents, k=3)

print("Top matching documents:")
for idx, doc, score in zip(indices, docs_retrieved, scores_retrieved):
    print(f"  - Index: {idx}, Score: {score:.4f}\n    Text: {doc[:200]}...")
# Out:
# Searching for: 'gravitational time dilation'
# Top matching documents:
#   - Index: 9274, Score: 15.1777
#     Text: Muon [SEP] In the Rossi–Hall experiment (1941), muons were used to observe the time dilation (or, alternatively, length contraction) predicted by special relativity, for the first time....
#   - Index: 139877, Score: 14.0688
#     Text: Surprise (emotion) [SEP] Pupil dilation and constriction can determine the valence of surprise from the action to the reaction of the individual. Positive valence to surprise is shown through a dilati...
#   - Index: 266, Score: 13.2422
#     Text: International Atomic Time [SEP] In the 1970s, it became clear that the clocks participating in TAI were ticking at different rates due to gravitational time dilation, and the combined TAI scale theref...

# %% [markdown]
# ### Contriever

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl (30.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 46.5 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.10.0

# %%
import torch
import faiss
import numpy as np
import torch.nn.functional as F
from transformers import AutoTokenizer, AutoModel

# Model Loading
print("Loading model and tokenizer...")
model_name = "facebook/contriever"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# Device setup (use GPU if available, otherwise CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
print(f"Model moved to device: {device}")

def encode_documents(docs, batch_size=16, max_length=256):
    """
    Encodes a list of documents into normalized embeddings using Contriever.
    Maintains the original function signature.
    """
    all_embeddings = []
    model.eval()
    with torch.no_grad():
        for i in range(0, len(docs), batch_size):
            batch_docs = docs[i:i+batch_size]
            # Tokenize and move tensors to the correct device
            inputs = tokenizer(batch_docs, padding=True, truncation=True, return_tensors="pt", max_length=max_length)
            inputs = {k: v.to(device) for k, v in inputs.items()}

            # Get model outputs
            outputs = model(**inputs)

            # Perform mean pooling (weighted by attention mask)
            attention_mask = inputs["attention_mask"]
            token_embeddings = outputs.last_hidden_state
            input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
            sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, dim=1)
            sum_mask = torch.clamp(input_mask_expanded.sum(dim=1), min=1e-9)
            mean_embeddings = sum_embeddings / sum_mask

            # Normalize embeddings to unit length (L2 norm) - Crucial for Inner Product
            normalized_embeddings = F.normalize(mean_embeddings, p=2, dim=1)

            # Move embeddings to CPU and convert to NumPy
            all_embeddings.append(normalized_embeddings.cpu().numpy())

    # Concatenate all batch embeddings into a single NumPy array
    embeddings = np.concatenate(all_embeddings, axis=0)
    return embeddings


print("Encoding documents...")
doc_embeddings = encode_documents(documents, batch_size=16)
print("Document embedding shape:", doc_embeddings.shape)

# --- Build Faiss Index using Inner Product ---
embedding_dim = doc_embeddings.shape[1]
# Use IndexFlatIP for Inner Product similarity
index = faiss.IndexFlatIP(embedding_dim)

# Faiss *requires* normalized vectors for IndexFlatIP.
# Although encode_documents already returns normalized vectors,
# it's good practice and sometimes necessary for specific Faiss indexes
# to explicitly normalize *again* right before adding.
print("Normalizing embeddings for Faiss (redundant but safe)...")
faiss.normalize_L2(doc_embeddings)

print("Adding documents to Faiss index...")
index.add(doc_embeddings)
print(f"Faiss index built with {index.ntotal} documents using Inner Product (IP).")
# --- End Faiss Indexing ---


# Dense retrieval function using Contriever and Faiss (Inner Product)
def dense_retrieve(query, index, original_docs, k=5, max_length=256):
    """
    Retrieves the top-k documents for a query using the Contriever model
    and a Faiss index (expecting normalized vectors and IP metric).
    Maintains the original function signature.
    """
    model.eval()
    with torch.no_grad():
        # Tokenize query and move to device
        inputs = tokenizer(query, return_tensors="pt", truncation=True, max_length=max_length)
        inputs = {k: v.to(device) for k, v in inputs.items()}

        # Get model outputs
        outputs = model(**inputs)

        # Perform the same mean pooling as for documents
        attention_mask = inputs["attention_mask"]
        token_embeddings = outputs.last_hidden_state
        input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
        sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, dim=1)
        sum_mask = torch.clamp(input_mask_expanded.sum(dim=1), min=1e-9)
        mean_embedding = sum_embeddings / sum_mask

        # Normalize the query embedding - Crucial for Inner Product
        normalized_embedding = F.normalize(mean_embedding, p=2, dim=1)

        # Move to CPU and convert to NumPy array
        query_embedding_np = normalized_embedding.cpu().numpy()

    # Faiss requires normalized query vector for IndexFlatIP search
    faiss.normalize_L2(query_embedding_np)

    # Search the Faiss index
    distances, indices = index.search(query_embedding_np, k)

    top_docs = [original_docs[i] for i in indices[0]]

    # Return indices and distances (scores)
    return indices[0], top_docs, distances[0]
# Out:
# Loading model and tokenizer...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/321 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Model moved to device: cuda
# Encoding documents...
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Document embedding shape: (216122, 768)
# Normalizing embeddings for Faiss (redundant but safe)...
# Adding documents to Faiss index...
# Faiss index built with 216122 documents using Inner Product (IP).

# %%
# Dense retrieval example usage
query = "gravitational time dilation"
print(f"\nSearching for query: '{query}'")
top_k_indices, docs_retrieved, top_k_scores = dense_retrieve(query, index, original_docs=documents, k=3)

print("Top matching documents:")
for i, doc, score in zip(top_k_indices, docs_retrieved, top_k_scores):
    print(f"  - Index: {i}, Score (Dot Product): {score:.4f}\n    Text: {doc[:200]}...")
# Out:
# Searching for query: 'gravitational time dilation'
# Top matching documents:
#   - Index: 9274, Score (Dot Product): 0.5993
#     Text: Muon [SEP] In the Rossi–Hall experiment (1941), muons were used to observe the time dilation (or, alternatively, length contraction) predicted by special relativity, for the first time....
#   - Index: 214834, Score (Dot Product): 0.5908
#     Text: Geometrodynamics [SEP] the geometry of Yang--Mills and gravitational gauge theories,...
#   - Index: 1137, Score (Dot Product): 0.5904
#     Text: Astronomer [SEP] time....

# %% [markdown]
# ## Base RAG pipeline with Gemini as Generator

# %%
# Retrieval function that allows method selection
def retrieve_documents(query, method='BM25', k=5):
    if method == 'BM25':
        _, docs, _ = bm25_retrieve(query, bm25, documents, k)
        return docs
    elif method == 'dense':
        _, docs, _ = dense_retrieve(query, index, original_docs=documents, k=k)
        return docs
    else:
        raise ValueError("Unsupported retrieval method. Use 'BM25' or 'dense'.")


# Text generation with Gemini API
import google.generativeai as genai

# Configure Gemini API (replace with your API key)
genai.configure(api_key="AIzaSyB4PodZpw89yrgLt6AFM01XcNX68iAQIsg") # my free Google key :) (will expire soon)

# Simple generator function
def text_generator(query, retrieved_docs):
    """Generates a response using Gemini with retrieved documents as context."""
    context = " ".join(retrieved_docs)
    prompt = f"Answer this question: {query} with the least amount of words possible (also only 1). Context: {context} answer: "
    response = genai.GenerativeModel('gemini-2.0-flash').generate_content(prompt)
    return response.text


# Main RAG pipeline function
def rag_pipeline(query, retrieval_method='BM25', k=5):
    # Retrieve documents using the selected method
    retrieved_docs = retrieve_documents(query, method=retrieval_method, k=k)
    print(f"Retrieved documents ({retrieval_method}):")
    for i, doc in enumerate(retrieved_docs):
        print(f"{i+1}. {doc[:150]}...")
    # Generate response using Gemini
    answer = text_generator(query, retrieved_docs)
    return answer


# Example usage:
query = "What is gravitational time dilation?"
# Test with BM25
answer_bm25 = rag_pipeline(query, retrieval_method='BM25', k=5)
print("\nAnswer (BM25):", answer_bm25)

# Test with dense retrieval
answer_dense = rag_pipeline(query, retrieval_method='dense', k=5)
print("\nAnswer (Dense):", answer_dense)
# Out:
# Retrieved documents (BM25):
# 1. Muon [SEP] In the Rossi–Hall experiment (1941), muons were used to observe the time dilation (or, alternatively, length contraction) predicted by spec...
# 2. Surprise (emotion) [SEP] Pupil dilation and constriction can determine the valence of surprise from the action to the reaction of the individual. Posi...
# 3. International Atomic Time [SEP] In the 1970s, it became clear that the clocks participating in TAI were ticking at different rates due to gravitationa...
# 4. M. C. Escher [SEP] BULLET::::- "Gravitation", (1952)...
# 5. Surprise (emotion) [SEP] BULLET::::- Pupil dilation mydriasis or pupil constriction miosis...
#
# Answer (BM25): Time's slowing near gravity.
#
# Retrieved documents (dense):
# 1. Geometrodynamics [SEP] the geometry of Yang--Mills and gravitational gauge theories,...
# 2. Moment of inertia [SEP] Notice that the distance to the center of oscillation of the seconds pendulum must be adjusted to accommodate different values...
# 3. Moment of inertia [SEP] The inertia tensor for a continuous body is given by...
# 4. Astronomer [SEP] time....
# 5. Moment of inertia [SEP] Section::::Motion in space of a rigid body, and the inertia matrix.:Angular momentum....
#
# Answer (Dense): Geometrodynamics.

# %% [markdown]
# ## Full experiment

# %% [markdown]
# ### Data Loading

# %% [markdown]
# Loading the whole NQ dataset.

# %%
# Load all expected outputs from the KILT NQ dev file
def load_all_nq_expected_outputs(filename):
    """Loads all queries and their gold answers from the KILT NQ dev file.
    Returns a dict {query: [gold_answer1, gold_answer2, ...]}."""
    expected = {}
    with open(filename, "r", encoding="utf-8") as f:
        for line in f:
            record = json.loads(line)
            query = record["input"].strip()
            golds = [out["answer"].strip() for out in record.get("output", []) if "answer" in out]
            if golds:
                expected[query] = golds
    return expected

# Load the full NQ dev dataset
expected_outputs = load_all_nq_expected_outputs("data/nq-dev-kilt.jsonl")
queries = list(expected_outputs.keys())
print(f"Loaded {len(queries)} queries from NQ.")

# For each query, retrieval_results[query] = [doc1, doc2, ..., doc50]
retrieval_results = {query: retrieve_documents(query, method='BM25', k=50) for query in queries}
# Out:
# Loaded 2837 queries from NQ.

# %% [markdown]
# ### T5-Small Fine-tuning

# %% [markdown]
# Building fine-tuning dataset.

# %%
# Add retrieved documents to the dataset
def augment_with_retrieved_documents(nq_dataset, retrieval_results):
    augmented_data = []
    for query, gold_answers in nq_dataset.items():

        # Retrieve corresponding documents for the query
        retrieved_docs = retrieval_results.get(query, [])

        # Target answers (since it's a multi-answer task, we just take the first answer)
        target_text = gold_answers[0]

        augmented_data.append({"query": query, "retrieved_docs": retrieved_docs, "gold_answer": target_text})
    return augmented_data

# Augment the NQ dataset with retrieved documents
augmented_dataset = augment_with_retrieved_documents(expected_outputs, retrieval_results)

# Save the augmented dataset to a new file for training
with open('augmented_nq_dataset.json', 'w') as f:
    json.dump(augmented_dataset, f, indent=4)

print(f"Augmented dataset saved with {len(augmented_dataset)} samples.")
# Out:
# Augmented dataset saved with 2837 samples.

# %% [markdown]
# Training loop.

# %%
import json
import torch
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from transformers import T5Tokenizer, T5ForConditionalGeneration
from torch.optim import AdamW
from functools import partial
import math
import gc

# %%
# Custom Dataset class
class QA_Dataset_FiD(Dataset):
    def __init__(self, augmented_data, tokenizer, max_input_length=512, max_target_length=128):
        self.data = augmented_data
        self.tokenizer = tokenizer
        self.max_input_length = max_input_length
        self.max_target_length = max_target_length

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        query = item["query"]
        gold_answer = item["gold_answer"]
        retrieved_docs = item["retrieved_docs"]

        input_encodings = []
        # retrieved_docs = retrieved_docs[:50]

        for doc in retrieved_docs:
            input_text = f"question: {query} context: {doc}"
            input_encoding = self.tokenizer(input_text, truncation=True, max_length=self.max_input_length)
            input_encodings.append(input_encoding)

        target_text = gold_answer
        target_encoding = self.tokenizer(target_text, truncation=True, max_length=self.max_target_length)

        return {
            'input_ids_list': [enc['input_ids'] for enc in input_encodings],
            'attention_mask_list': [enc['attention_mask'] for enc in input_encodings],
            'labels': target_encoding['input_ids']
        }

# Load the augmented dataset
with open('augmented_nq_dataset.json', 'r') as f:
    augmented_dataset = json.load(f)

# Split the dataset
train_data, test_data = train_test_split(augmented_dataset, test_size=0.2, random_state=42)

# Initialize the tokenizer
tokenizer = T5Tokenizer.from_pretrained("t5-small")

# Create Datasets
train_dataset = QA_Dataset_FiD(train_data, tokenizer)
test_dataset = QA_Dataset_FiD(test_data, tokenizer)

# Custom Collate Function for FiD
def collate_fn_fid(batch, tokenizer, max_docs_per_item=10, max_input_length=512, max_target_length=128):
    actual_max_docs_in_batch = max(len(item['input_ids_list']) for item in batch) if batch else 0
    max_docs_this_batch = min(actual_max_docs_in_batch, max_docs_per_item)

    max_len_input = max_input_length
    max_len_target = max_target_length

    all_input_ids = []
    all_attention_masks = []
    all_labels = []

    pad_token_id = tokenizer.pad_token_id
    label_pad_token_id = -100

    for item in batch:
        item_input_ids = []
        item_attention_masks = []

        # Process up to max_docs_this_batch, handling items with fewer docs
        num_docs_to_process = min(len(item['input_ids_list']), max_docs_this_batch)

        # Pad up to max_docs_per_item for consistent tensor shapes across batches
        for i in range(max_docs_per_item):
            if i < num_docs_to_process:
                input_ids = item['input_ids_list'][i][:max_len_input]
                attention_mask = item['attention_mask_list'][i][:max_len_input]

                padding_length = max_len_input - len(input_ids)
                input_ids = input_ids + ([pad_token_id] * padding_length)
                attention_mask = attention_mask + ([0] * padding_length)
            else:
                # Pad with empty docs if item has < max_docs_per_item
                input_ids = [pad_token_id] * max_len_input
                attention_mask = [0] * max_len_input

            item_input_ids.append(torch.tensor(input_ids, dtype=torch.long))
            item_attention_masks.append(torch.tensor(attention_mask, dtype=torch.long))

        if len(item_input_ids) != max_docs_per_item:
             print(f"Warning: Mismatch in expected docs {max_docs_per_item} vs actual {len(item_input_ids)}")

        all_input_ids.append(torch.stack(item_input_ids))
        all_attention_masks.append(torch.stack(item_attention_masks))

        labels = item['labels'][:max_len_target]
        label_padding_length = max_len_target - len(labels)
        padded_labels = labels + ([label_pad_token_id] * label_padding_length)
        all_labels.append(torch.tensor(padded_labels, dtype=torch.long))

    if not all_input_ids:
        return {
            'input_ids': torch.empty(0, max_docs_per_item, max_len_input, dtype=torch.long),
            'attention_mask': torch.empty(0, max_docs_per_item, max_len_input, dtype=torch.long),
            'labels': torch.empty(0, max_len_target, dtype=torch.long)
        }

    batch_input_ids = torch.stack(all_input_ids)
    batch_attention_masks = torch.stack(all_attention_masks)
    batch_labels = torch.stack(all_labels)

    return {
        'input_ids': batch_input_ids,
        'attention_mask': batch_attention_masks,
        'labels': batch_labels
    }

# --- DataLoader Setup ---
per_device_batch_size = 1
num_epochs = 1 # As per paper
effective_batch_size = 64 # As per paper
max_docs_per_item = 40

# Calculate gradient accumulation steps
if effective_batch_size % per_device_batch_size != 0:
    raise ValueError("Effective batch size must be divisible by per-device batch size")
gradient_accumulation_steps = effective_batch_size // per_device_batch_size

train_dataloader = DataLoader(train_dataset, batch_size=per_device_batch_size, shuffle=True,
                              collate_fn=partial(collate_fn_fid, tokenizer=tokenizer, max_docs_per_item=max_docs_per_item))
test_dataloader = DataLoader(test_dataset, batch_size=per_device_batch_size, shuffle=False,
                             collate_fn=partial(collate_fn_fid, tokenizer=tokenizer, max_docs_per_item=max_docs_per_item))
# --- End DataLoader Setup ---


# --- Model, Optimizer, and Device Setup ---
model = T5ForConditionalGeneration.from_pretrained("t5-small")
initial_lr = 5e-5 # As per paper
optimizer = AdamW(model.parameters(), lr=initial_lr, weight_decay=1e-2) # As per paper
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# --- End Model Setup ---


# --- Warmup and Training Steps Calculation ---
num_update_steps_per_epoch = math.ceil(len(train_dataloader) / gradient_accumulation_steps)
if num_update_steps_per_epoch == 0:
     raise ValueError("Train dataloader is effectively empty with gradient accumulation. Check dataset size and batch sizes.")

total_training_steps = num_epochs * num_update_steps_per_epoch
warmup_proportion = 0.05 # 5% as per paper
num_warmup_steps = int(total_training_steps * warmup_proportion)
global_optimizer_step = 0
# --- End Warmup Calculation ---


print(f"--- Configuration ---")
print(f"Using device: {device}")
print(f"Per-device batch size: {per_device_batch_size}")
print(f"Effective batch size: {effective_batch_size}")
print(f"Gradient Accumulation steps: {gradient_accumulation_steps}")
print(f"Max docs per item: {max_docs_per_item}")
print(f"Num Epochs: {num_epochs}")
print(f"Initial Learning Rate: {initial_lr}")
print(f"Weight Decay: {optimizer.param_groups[0]['weight_decay']}")
print(f"Train Dataloader size (batches): {len(train_dataloader)}")
print(f"Optimizer steps per epoch: {num_update_steps_per_epoch}")
print(f"Total optimizer steps: {total_training_steps}")
print(f"Warmup optimizer steps: {num_warmup_steps}")
print(f"--------------------")


# --- Training Loop with Gradient Accumulation, FiD, and Warmup ---
model.zero_grad()

for epoch in range(num_epochs):
    model.train()
    total_loss_accumulated = 0.0
    processed_batches_count = 0

    for i, batch in enumerate(train_dataloader):

        input_ids_batch = batch['input_ids'].to(device)
        attention_mask_batch = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        if input_ids_batch.numel() == 0:
            print(f"Warning: Skipping empty batch at step {i}")
            continue

        bsz, n_docs, seq_len = input_ids_batch.shape
        target_seq_len = labels.shape[-1]

        if labels.dim() == 3 and labels.shape[1] == 1:
            labels = labels.squeeze(1)
        elif labels.dim() != 2:
            print(f"Unexpected labels shape: {labels.shape} at step {i}. Skipping batch.")
            continue

        # --- FiD Forward Pass ---
        # 1. Prepare and Run Encoder
        input_ids_enc = input_ids_batch.view(bsz * n_docs, seq_len)
        attention_mask_enc = attention_mask_batch.view(bsz * n_docs, seq_len)

        encoder_outputs = model.encoder(
            input_ids=input_ids_enc,
            attention_mask=attention_mask_enc,
            return_dict=True
        )

        # 2. Prepare Inputs for Decoder
        cross_attention_mask = attention_mask_batch.view(bsz, n_docs * seq_len)

        # 3. Run Decoder
        outputs = model(
            labels=labels,
            encoder_outputs=encoder_outputs,
            attention_mask=cross_attention_mask
        )
        loss = outputs.loss

        if loss is None:
            print(f"Warning: Loss is None at step {i}. Skipping backward/step.")
            continue

        # --- Scale Loss for Gradient Accumulation ---
        # Normalize loss to average gradients correctly
        scaled_loss = loss / gradient_accumulation_steps
        total_loss_accumulated += loss.item()
        processed_batches_count += 1

        # --- Backward Pass (Accumulate Gradients) ---
        scaled_loss.backward()

        # --- Optimizer Step ---
        # Check if we have processed enough batches for one optimizer update
        if (i + 1) % gradient_accumulation_steps == 0:

            # --- Optional: Gradient Clipping (Common practice) ---
            # torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            # --- Apply Linear Warmup ---
            if global_optimizer_step < num_warmup_steps:
                lr_scale = float(global_optimizer_step) / float(max(1, num_warmup_steps))
            else:
                lr_scale = 1.0

            for param_group in optimizer.param_groups:
                param_group['lr'] = initial_lr * lr_scale
            # --- End Linear Warmup ---

            # --- Perform Optimizer Step ---
            optimizer.step()

            # --- Zero Gradients for the next accumulation cycle ---
            optimizer.zero_grad()

            # --- Increment global OPTIMIZER step counter ---
            global_optimizer_step += 1

            if global_optimizer_step % 10 == 0:
                 current_lr = optimizer.param_groups[0]['lr']
                 recent_loss = total_loss_accumulated / processed_batches_count if processed_batches_count > 0 else 0.0
                 print(f"Epoch: {epoch}, Opt Step: {global_optimizer_step}/{total_training_steps}, LR: {current_lr:.2e}, Avg Epoch Loss So Far: {recent_loss:.4f}")

    # --- End of Epoch ---
    avg_epoch_loss = total_loss_accumulated / processed_batches_count if processed_batches_count > 0 else 0
    print(f"Epoch {epoch} Finished - Average Loss: {avg_epoch_loss:.4f}")

    # --- Save Model Checkpoint Per Epoch ---
    output_dir = f"finetuned_t5_model_fid"
    model.save_pretrained(output_dir)
    tokenizer.save_pretrained(output_dir)
    print(f"Model checkpoint saved to {output_dir}")

print("Training finished.")
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# --- Configuration ---
# Using device: cuda
# Per-device batch size: 1
# Effective batch size: 64
# Gradient Accumulation steps: 64
# Max docs per item: 40
# Num Epochs: 1
# Initial Learning Rate: 5e-05
# Weight Decay: 0.01
# Train Dataloader size (batches): 2269
# Optimizer steps per epoch: 36
# Total optimizer steps: 36
# Warmup optimizer steps: 1
# --------------------
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# Epoch: 0, Opt Step: 10/36, LR: 5.00e-05, Avg Epoch Loss So Far: 4.4274
# Epoch: 0, Opt Step: 20/36, LR: 5.00e-05, Avg Epoch Loss So Far: 4.2880
# Epoch: 0, Opt Step: 30/36, LR: 5.00e-05, Avg Epoch Loss So Far: 4.2540
# Epoch 0 Finished - Average Loss: 4.2101
# Model checkpoint saved to finetuned_t5_model_fid
# Training finished.

# %% [markdown]
# ### ERAG eval and End-to-end eval

# %%
# !pip install erag

import json
import re
import string
import time
import erag
import os
import pickle
import scipy.stats as stats
# Out:
# Collecting erag
#   Downloading erag-0.0.1.tar.gz (7.8 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pytrec_eval==0.5 (from erag)
#   Downloading pytrec_eval-0.5.tar.gz (15 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: erag, pytrec_eval
#   Building wheel for erag (pyproject.toml) ... done
#   Created wheel for erag: filename=erag-0.0.1-py3-none-any.whl size=7176 sha256=5e018bb9bda0e422fc905eb20efda02a21688d9de1c69f90b7fcf1bca85c6c41
#   Stored in directory: /root/.cache/pip/wheels/36/db/db/48902dfbd5390e49a5c925b591d60a6b004e4e00cf8f7b48cc
#   Building wheel for pytrec_eval (setup.py) ... done
#   Created wheel for pytrec_eval: filename=pytrec_eval-0.5-cp311-cp311-linux_x86_64.whl size=308655 sha256=08266c467ab4975807db6bfa0659fa51b3cd04191131be9636ffbd59a575fb23
#   Stored in directory: /root/.cache/pip/wheels/0f/89/42/86aecdb99975f1840c27bc37fdfed72116abcf82e2c9dc76a8
# Successfully built erag pytrec_eval
# Installing collected packages: pytrec_eval, erag
# Successfully installed erag-0.0.1 pytrec_eval-0.5

# %% [markdown]
# T5 text generator

# %%
from transformers.modeling_outputs import BaseModelOutput

def T5_text_generator(
    queries_and_documents: dict,
    model: T5ForConditionalGeneration,
    tokenizer: T5Tokenizer,
    device: torch.device,
    max_input_len: int = 512,
    max_output_len: int = 128,
    num_beams: int = 4,
    **generate_kwargs):
    """
    Generates answers for multiple queries using a fine-tuned T5 FiD model.

    Args:
        queries_and_documents: Dictionary where keys are query strings and
                               values are lists of retrieved document strings.
        model: The loaded fine-tuned T5ForConditionalGeneration model (on device).
        tokenizer: The loaded corresponding T5Tokenizer.
        device: The torch.device where the model is located.
        max_input_len: Max sequence length for each (query + doc) input.
        max_output_len: Max sequence length for the generated answer.
        num_beams: Number of beams for beam search generation.
        **generate_kwargs: Additional keyword arguments passed to model.generate().

    Returns:
        Dictionary where keys are the input query strings and values are the
        corresponding generated answer strings (or an error message if no docs provided).
    """
    model.eval()
    results = {}
    pad_token_id = tokenizer.pad_token_id

    print(f"Generating answers for {len(queries_and_documents)} queries...")
    start_time_total = time.time()

    # Iterate through each query and its associated documents
    for i, (query, retrieved_docs) in enumerate(queries_and_documents.items()):
        start_time_query = time.time()
        print(f"  Processing query {i+1}/{len(queries_and_documents)}: \"{query[:50]}...\"")

        if not retrieved_docs:
            print(f"    Warning: No documents found for query {i+1}. Skipping.")
            results[query] = "Error: No documents provided for this query."
            continue

        all_input_ids = []
        all_attention_masks = []

        # --- Core FiD Generation Logic (applied per query) ---

        # 1. Preprocess and Tokenize each document for the CURRENT query
        for doc in retrieved_docs:
            input_text = f"question: {query} context: {doc}"
            encoding = tokenizer(
                input_text,
                truncation=True,
                max_length=max_input_len,
                padding="max_length",
                return_attention_mask=True,
                add_special_tokens=True
            )
            all_input_ids.append(torch.tensor(encoding['input_ids']))
            all_attention_masks.append(torch.tensor(encoding['attention_mask']))

        # 2. Stack inputs and move to device for CURRENT query
        input_ids_stacked = torch.stack(all_input_ids).to(device)
        attention_mask_stacked = torch.stack(all_attention_masks).to(device)
        num_docs, seq_len = input_ids_stacked.shape

        # Use no_grad context for efficiency during inference
        with torch.no_grad():
            # 3. Encoder Pass for CURRENT query
            raw_encoder_outputs = model.encoder(
                input_ids=input_ids_stacked,
                attention_mask=attention_mask_stacked,
                return_dict=True
            )

            # 4. Reshape Encoder Outputs for Generate
            encoder_hidden_states_reshaped = raw_encoder_outputs.last_hidden_state.view(
                1, num_docs * seq_len, raw_encoder_outputs.last_hidden_state.size(-1)
            )
            encoder_outputs_for_generate = BaseModelOutput(
                last_hidden_state=encoder_hidden_states_reshaped
            )

            # 5. Prepare Cross-Attention Mask
            cross_attention_mask_reshaped = attention_mask_stacked.view(1, num_docs * seq_len)

            # 6. Generation (Decoder) using model.generate() for CURRENT query
            generated_ids = model.generate(
                encoder_outputs=encoder_outputs_for_generate, # Reshaped encoder outputs
                attention_mask=cross_attention_mask_reshaped, # Mask for cross-attention
                max_length=max_output_len,
                num_beams=num_beams,
                early_stopping=True,
                **generate_kwargs
            )

        # 7. Decode the generated token IDs back to text
        generated_text = tokenizer.decode(
            generated_ids[0],
            skip_special_tokens=True
        )

        # Store the generated answer in the results dictionary
        results[query] = generated_text.strip()
        end_time_query = time.time()
        # print(f"    Generated answer in {end_time_query - start_time_query:.2f} seconds.")

    end_time_total = time.time()
    print(f"Finished generating all answers in {end_time_total - start_time_total:.2f} seconds.")

    # Return the dictionary containing {query: answer} pairs
    return results

# %% [markdown]
# ### T5 Model Loading

# %%
from functools import partial

model_path = "finetuned_t5_model_fid"
max_input_len = 512
max_output_len = 128
num_beams_eval = 4

# Load the fine-tuned model and tokenizer
print(f"Loading model from: {model_path}")
model = T5ForConditionalGeneration.from_pretrained(model_path)
tokenizer = T5Tokenizer.from_pretrained(model_path)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

print(f"Model loaded on device: {device}")
# Out:
# Loading model from: finetuned_t5_model_fid
# Model loaded on device: cuda

# %%
# Create a partial function that has model, tokenizer, device, etc. pre-filled
t5_generator_for_eval = partial(
    T5_text_generator,
    model=model,
    tokenizer=tokenizer,
    device=device,
    max_input_len=max_input_len,
    max_output_len=max_output_len,
    num_beams=num_beams_eval
)

# %% [markdown]
# Loading the Test set queries

# %%
test_queries = set(item['query'] for item in test_data)
print(f"\nExtracted {len(test_queries)} unique queries for the test set.")

# Create the test split dictionaries using the test queries
test_expected_outputs = {
    query: answers
    for query, answers in expected_outputs.items()
    if query in test_queries
}

test_retrieval_results = {
    query: docs
    for query, docs in retrieval_results.items()
    if query in test_queries
}

print("\nVerification:")
print(f"Size of test_expected_outputs: {len(test_expected_outputs)}")
print(f"Size of test_retrieval_results: {len(test_retrieval_results)}")
# Out:
# Extracted 568 unique queries for the test set.
#
# Verification:
# Size of test_expected_outputs: 568 (should match test_data size)
# Size of test_retrieval_results: 568 (should match test_data size)

# %% [markdown]
# Defining the evaluation function for Erag

# %%
# Define the Exact Match evaluation function
def normalize_answer(s):
    """Converts text to lowercase, removes punctuation and extra spaces."""
    return ' '.join(''.join(ch for ch in s.lower() if ch not in string.punctuation).split())

def exact_match_metric(generated_outputs, expected_outputs):
    """Computes if the generated text (normalized) exactly matches one of the gold answers (normalized).
    Returns a dict {query: score}, where score is 1 or 0."""
    return {query: 1 if any(normalize_answer(gen) == normalize_answer(gold) for gold in expected_outputs.get(query, [])) else 0 for query, gen in generated_outputs.items()}

# %% [markdown]
# Evaluation Loop

# %%
# Create the log directory if it doesn't exist
LOG_DIR = "logs"
if not os.path.exists(LOG_DIR):
    os.makedirs(LOG_DIR)

# Define checkpoint file
CHECKPOINT_FILE = "experiment_checkpoint.pkl"

# Load checkpoint if it exists, otherwise initialize an empty dictionary
if os.path.exists(CHECKPOINT_FILE):
    with open(CHECKPOINT_FILE, "rb") as f:
        checkpoint = pickle.load(f)
    print("Checkpoint loaded.")
else:
    checkpoint = {}
    print("No checkpoint found, starting from scratch.")



# Define values for K (number of retrieved documents) and retrieval methods
k_values = [40]
retriever_methods = ['BM25'] # , 'dense'

# Load existing correlations from checkpoint
correlations = {method: checkpoint.get(method, {}) for method in retriever_methods}

# Iterate over retrieval methods and values of K
for method in retriever_methods:
    for k in k_values:
        if k in checkpoint.get(method, {}):
            print(f"Skipping {method} with K={k} (already processed).")
            continue

        print(f"\n--- Processing {method} with K = {k} ---")
        try:
            # Define retrieval metrics based on k
            retrieval_metrics = {f'P_{k}', f'success_{k}'}

            # Evaluate retrieval and generation
            erag_results = erag.eval(
                retrieval_results=test_retrieval_results,
                expected_outputs=test_expected_outputs,
                text_generator=t5_generator_for_eval,
                downstream_metric=exact_match_metric,
                retrieval_metrics=retrieval_metrics
            )

            # Save per-query results
            per_input_file = os.path.join(LOG_DIR, f"per_input_{method}_K{k}.json")
            with open(per_input_file, "w", encoding="utf-8") as f:
                json.dump(erag_results['per_input'], f, ensure_ascii=False, indent=2)
            print(f"Saved per-input results in {per_input_file}.")

            # Save aggregated results
            aggregated_file = os.path.join(LOG_DIR, f"aggregated_{method}_K{k}.json")
            with open(aggregated_file, "w", encoding="utf-8") as f:
                json.dump(erag_results['aggregated'], f, ensure_ascii=False, indent=2)
            print(f"Saved aggregated results in {aggregated_file}.")

            # Generate end-to-end responses
            end_to_end_generated = t5_generator_for_eval(test_retrieval_results)
            e2e_scores_dict = exact_match_metric(end_to_end_generated, test_expected_outputs)

            # Save end-to-end scores
            e2e_file = os.path.join(LOG_DIR, f"end_to_end_{method}_K{k}.json")
            with open(e2e_file, "w", encoding="utf-8") as f:
                json.dump(e2e_scores_dict, f, ensure_ascii=False, indent=2)
            print(f"Saved end-to-end scores in {e2e_file}.")

            # --- Compute correlation between erag and end-to-end scores ---
            end_to_end_scores = [e2e_scores_dict.get(query, 0) for query in test_queries]

            local_corr = {}
            for metric_key in retrieval_metrics:
                eRAG_scores = [erag_results['per_input'][query].get(metric_key, None) for query in test_queries]
                eRAG_scores = [score for score in eRAG_scores if score is not None]

                if len(eRAG_scores) != len(end_to_end_scores):
                    print(f"Warning: dimension mismatch for {method}, metric {metric_key}, K={k}")

                # Compute correlation if variance exists
                spearman_corr, spearman_p = stats.spearmanr(eRAG_scores, end_to_end_scores)
                kendall_corr, kendall_p = stats.kendalltau(eRAG_scores, end_to_end_scores)
                local_corr[metric_key] = {
                    'spearman': spearman_corr,
                    'kendall': kendall_corr,
                    'num_queries': len(eRAG_scores)
                }
                print(f"\nFor metric {metric_key} ({method}, K={k}):")
                print(f"  Spearman correlation: {spearman_corr:.3f} (p={spearman_p:.3f})")
                print(f"  Kendall correlation:   {kendall_corr:.3f} (p={kendall_p:.3f})")

            # Update checkpoint
            checkpoint[method][k] = local_corr
            with open(CHECKPOINT_FILE, "wb") as f:
                pickle.dump(checkpoint, f)
            print(f"Checkpoint updated for {method} with K={k}.")

        except Exception as e:
            print(f"Error for {method} with K={k}: {e}")
            time.sleep(10)
            continue

print("\n--- Final correlation summary ---")
print(correlations)
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   Processing query 145/568: "when did the the regulatory reform (fire safety) o..."
#   Processing query 146/568: "who want to be a millionaire calls his dad..."
#   Processing query 147/568: "two examples where low voltage transformers are us..."
#   Processing query 148/568: "what causes cracked skin at the corners of your mo..."
#   Processing query 149/568: "who had the longest tenure as moderator on meet th..."
#   Processing query 150/568: "industrial city in germany on the rhine herne cana..."
#   Processing query 151/568: "who sings the song it ain't me..."
#   Processing query 152/568: "where does the optic nerve cross the midline ​..."
#   Processing query 153/568: "who did the central powers defeat on the eastern f..."
#   Processing query 154/568: "who was the captain of the mayflower when it took ..."
#   Processing query 155/568: "when does the cannes film festival take place..."
#   Processing query 156/568: "where was held the first session of muslim league..."
#   Processing query 157/568: "what is the largest magnitude earthquake that has ..."
#   Processing query 158/568: "when does the champions league quarter finals star..."
#   Processing query 159/568: "when did the term sustainability start to be used..."
#   Processing query 160/568: "fast & furious 8 release date in india..."
#   Processing query 161/568: "when does the movie jeepers creepers come out..."
#   Processing query 162/568: "the joint between a coxal bone of the pelvis and t..."
#   Processing query 163/568: "who played cosette in les miserables on broadway..."
#   Processing query 164/568: "whats the difference between tomato paste and toma..."
#   Processing query 165/568: "what type of plate boundary is associated with ice..."
#   Processing query 166/568: "who plays jimmy's mom in 8 mile..."
#   Processing query 167/568: "actress who plays brad pitts wife in war machine..."
#   Processing query 168/568: "who is the book of galatians written to..."
#   Processing query 169/568: "what is the name of the hyena in lion king..."
#   Processing query 170/568: "when does the new death of superman come out..."
#   Processing query 171/568: "when was a series of unfortunate events published..."
#   Processing query 172/568: "what nfl player has the most nfl rings..."
#   Processing query 173/568: "when did canada get rid of the death penalty..."
#   Processing query 174/568: "when did we first put a rover on mars..."
#   Processing query 175/568: "who plays the mouse in alice in wonderland..."
#   Processing query 176/568: "rain sleet or snow that contains a high concentrat..."
#   Processing query 177/568: "who plays jack skellington in nightmare before chr..."
#   Processing query 178/568: "make it or break it who goes to the olympics..."
#   Processing query 179/568: "where was the movie i am number 4 filmed..."
#   Processing query 180/568: "who is the current defence against the dark arts t..."
#   Processing query 181/568: "what does g stand for in ncis los angeles..."
#   Processing query 182/568: "who sang i'm gonna run away from you..."
#   Processing query 183/568: "what are the two extracellular fluid compartments ..."
#   Processing query 184/568: "who wrote shes always a woman to me..."
#   Processing query 185/568: "how many times have real madrid won the champions ..."
#   Processing query 186/568: "who invented the glasses that give sight to the bl..."
#   Processing query 187/568: "who are the permanent member of un security counci..."
#   Processing query 188/568: "when did the first wireless beats come out..."
#   Processing query 189/568: "who presides over the joint sessions of parliament..."
#   Processing query 190/568: "who is the girl in the hinder video lips of an ang..."
#   Processing query 191/568: "who helped the british in the french and indian wa..."
#   Processing query 192/568: "who is mowgli's main enemy in the jungle book..."
#   Processing query 193/568: "what information is displayed in clear text from t..."
#   Processing query 194/568: "who was elected the president of constituent assem..."
#   Processing query 195/568: "what is the meaning of gorakh dhanda in urdu..."
#   Processing query 196/568: "when was the last time minnesota vikings was in th..."
#   Processing query 197/568: "prior to 1948 north and south vietnam were a part ..."
#   Processing query 198/568: "where do the florida marlins have spring training..."
#   Processing query 199/568: "when does star trek discovery season 1 end..."
#   Processing query 200/568: "when does rick and morty play on tv..."
#   Processing query 201/568: "when is the new dumping ground coming out 2017..."
#   Processing query 202/568: "who sings the song i'll never forget you..."
#   Processing query 203/568: "who was the leader of the soviet union when the be..."
#   Processing query 204/568: "who plays lindsay denton in line of duty..."
#   Processing query 205/568: "when was hitchhiker's guide to the galaxy made..."
#   Processing query 206/568: "who plays kevins shrink on kevin probably saves th..."
#   Processing query 207/568: "which episode does gideon die in criminal minds..."
#   Processing query 208/568: "who won the 2018 women's royal rumble match..."
#   Processing query 209/568: "who was the first woman to win who wants to be a m..."
#   Processing query 210/568: "who wrote he ain't heavy he's my brother lyrics..."
#   Processing query 211/568: "who plays connor's mom in madeas christmas..."
#   Processing query 212/568: "i was a great islamic scholar and mathematician wh..."
#   Processing query 213/568: "cast of the movie pride of the marines..."
#   Processing query 214/568: "when did seattle slew win the triple crown..."
#   Processing query 215/568: "how many writes does a flash drive have..."
#   Processing query 216/568: "who destroyed the first temple and exiled the two ..."
#   Processing query 217/568: "when was child benefit paid for the first child..."
#   Processing query 218/568: "what was the initial effect of the transition from..."
#   Processing query 219/568: "who has the most green jackets from the masters..."
#   Processing query 220/568: "who played the mom on what's eating gilbert grape..."
#   Processing query 221/568: "when was the first star wars film released..."
#   Processing query 222/568: "what mall did they use in back to the future..."
#   Processing query 223/568: "what does rt mean on a dodge car..."
#   Processing query 224/568: "what written material is included in the talmud..."
#   Processing query 225/568: "when did france and belgium invade the ruhr..."
#   Processing query 226/568: "who won the mens figure skating in 2018 olympics..."
#   Processing query 227/568: "the recipient of first jnanpith award was an autho..."
#   Processing query 228/568: "who has played raoul in phantom of the opera..."
#   Processing query 229/568: "who discovered that neural communication between c..."
#   Processing query 230/568: "who did the mavericks beat in the finals..."
#   Processing query 231/568: "a political leader during the roman empire was cal..."
#   Processing query 232/568: "what was the religion in persia before islam..."
#   Processing query 233/568: "who signed the declaration of independence for mar..."
#   Processing query 234/568: "who rebuilt the temple after the babylonian captiv..."
#   Processing query 235/568: "who is command sergeant major of the army..."
#   Processing query 236/568: "where will the next summer and winter olympics be ..."
#   Processing query 237/568: "what are the ranks in the us navy..."
#   Processing query 238/568: "who owns the majority of the us debt..."
#   Processing query 239/568: "where is dakar located on the world map..."
#   Processing query 240/568: "who is credited with the discovery of the neutron..."
#   Processing query 241/568: "types of skiing in the winter olympics 2018..."
#   Processing query 242/568: "who did the 49ers beat in the super bowls..."
#   Processing query 243/568: "when was the south asian association for regional ..."
#   Processing query 244/568: "is jaffa cakes a biscuit or a cake..."
#   Processing query 245/568: "when was the first commercial cell phone released..."
#   Processing query 246/568: "who is the lead singer of collective soul..."
#   Processing query 247/568: "the oligodynamic effect is a phenomenon that descr..."
#   Processing query 248/568: "who was allowed to vote in the roman republic..."
#   Processing query 249/568: "who's the model on let's make a deal..."
#   Processing query 250/568: "where does the last name hansen come from..."
#   Processing query 251/568: "what channel is abc on in phoenix arizona..."
#   Processing query 252/568: "who played jennifer in back to the future..."
#   Processing query 253/568: "who cooks for the president of the united states..."
#   Processing query 254/568: "where is the inscription on the statue of liberty..."
#   Processing query 255/568: "who makes the important government decisions in an..."
#   Processing query 256/568: "what was the main characteristic of post-world war..."
#   Processing query 257/568: "what is on top of us capitol building..."
#   Processing query 258/568: "who was running as vice president in 1984..."
#   Processing query 259/568: "who took the first steps on the moon in 1969..."
#   Processing query 260/568: "who played desmond doss father in hacksaw ridge..."
#   Processing query 261/568: "where can the mona lisa be found today..."
#   Processing query 262/568: "original cast of natasha pierre and the great come..."
#   Processing query 263/568: "which president supported the creation of the envi..."
#   Processing query 264/568: "who plays the saint of killers on preacher..."
#   Processing query 265/568: "when did sierra nevada brewery open in asheville..."
#   Processing query 266/568: "who plays the mother of howard on big bang theory..."
#   Processing query 267/568: "who sang the song if loving you is wrong i don't w..."
#   Processing query 268/568: "when was the last time the eu was audited..."
#   Processing query 269/568: "who plays yoda in revenge of the sith..."
#   Processing query 270/568: "when did the vikings first sail and reach britain..."
#   Processing query 271/568: "when is the opening ceremonies of the olympics 201..."
#   Processing query 272/568: "who sang theme song for dukes of hazard..."
#   Processing query 273/568: "who determines the rules of the us house and us se..."
#   Processing query 274/568: "list the seven gifts of the holy spirit..."
#   Processing query 275/568: "where is beijing located on the world map..."
#   Processing query 276/568: "a player that can shoot pass or dribble is conside..."
#   Processing query 277/568: "how many quarterbacks have a receiving touchdown i..."
#   Processing query 278/568: "who wrote ain't living long like this..."
#   Processing query 279/568: "when do love and hip hop new york come back on..."
#   Processing query 280/568: "when did season 4 of glee come out..."
#   Processing query 281/568: "who were the major countries involved in the cold ..."
#   Processing query 282/568: "who directed the best years of our lives..."
#   Processing query 283/568: "how many characters are present in icd-10 codes..."
#   Processing query 284/568: "where is the heart of palm on a palm tree..."
#   Processing query 285/568: "what was the name of darth vader star destroyer..."
#   Processing query 286/568: "what does the air gap do on a dishwasher..."
#   Processing query 287/568: "who sang smoke gets in your eyes first..."
#   Processing query 288/568: "what is the 180 degree line of longitude called..."
#   Processing query 289/568: "when did the last volcano erupt in iceland..."
#   Processing query 290/568: "who plays ser davos in game of thrones..."
#   Processing query 291/568: "who hit the first home run in the houston astrodom..."
#   Processing query 292/568: "where did the idea of a unicorn come from..."
#   Processing query 293/568: "where does fungi go on a food web..."
#   Processing query 294/568: "who is the real killer in basic instinct 2..."
#   Processing query 295/568: "which material is the heaviest in term of density..."
#   Processing query 296/568: "who has scored the most half centuries in test cri..."
#   Processing query 297/568: "who won the medals in men's figure skating 2018..."
#   Processing query 298/568: "who played the mom in the partridge family..."
#   Processing query 299/568: "star wars episode ii attack of the clones characte..."
#   Processing query 300/568: "what type of business is chamber of commerce..."
#   Processing query 301/568: "where is the left anterior descending artery locat..."
#   Processing query 302/568: "what is the real name of our sun..."
#   Processing query 303/568: "who plays the scary nun in the conjuring 2..."
#   Processing query 304/568: "how does the cash cab guy read the questions..."
#   Processing query 305/568: "who grows the most coffee in the world..."
#   Processing query 306/568: "when did come fly with me come out..."
#   Processing query 307/568: "when did the second it movie come out..."
#   Processing query 308/568: "who sings the christmas song all i want for christ..."
#   Processing query 309/568: "who used the word physiology for the first time..."
#   Processing query 310/568: "who won season 5 of hell's kitchen..."
#   Processing query 311/568: "star cast of ab tumhare hawale watan sathiyon..."
#   Processing query 312/568: "who played the jewish man in coming to america..."
#   Processing query 313/568: "who were the twins that played for kentucky..."
#   Processing query 314/568: "when did frank sinatra first sing new york new yor..."
#   Processing query 315/568: "who is the first wife on sister wives..."
#   Processing query 316/568: "who won season 16 on dancing with the stars..."
#   Processing query 317/568: "who sings i just want to use your love tonight..."
#   Processing query 318/568: "forney's sister in where the heart is..."
#   Processing query 319/568: "when did the study of media effects begin..."
#   Processing query 320/568: "when did the golden state warriors win the finals..."
#   Processing query 321/568: "when was the young and the restless first aired..."
#   Processing query 322/568: "how many episodes in game if thrones season 7..."
#   Processing query 323/568: "who are the only 2 families that have had 3 genera..."
#   Processing query 324/568: "who founded mission nuestra senora de la soledad..."
#   Processing query 325/568: "when did the isle of wight become an island..."
#   Processing query 326/568: "where can you find convergent boundaries on earth..."
#   Processing query 327/568: "what was the emperor name in star wars..."
#   Processing query 328/568: "who played the female lead in the 1942 film casabl..."
#   Processing query 329/568: "when did the new day win the tag team titles..."
#   Processing query 330/568: "where does the last name tavarez come from..."
#   Processing query 331/568: "who wrote from now on from the greatest showman..."
#   Processing query 332/568: "who is the authority or governing body of mca..."
#   Processing query 333/568: "where does sound travel fastest solid liquid or ga..."
#   Processing query 334/568: "who enforces the charter of rights and freedoms..."
#   Processing query 335/568: "who is credited with developing the geocentric vie..."
#   Processing query 336/568: "who was the successful commanding general of the n..."
#   Processing query 337/568: "who sang the theme song to step by step..."
#   Processing query 338/568: "who won last year's grand national 2017..."
#   Processing query 339/568: "what was the name of the first continent..."
#   Processing query 340/568: "who was the ruler of england in 1616..."
#   Processing query 341/568: "when does elijah first appear in vampire diaries..."
#   Processing query 342/568: "who does the voice of nala in the lion king..."
#   Processing query 343/568: "who made the first spanish landing on the mainland..."
#   Processing query 344/568: "where did they film the royal tv series..."
#   Processing query 345/568: "when were the words under god added to the pledge..."
#   Processing query 346/568: "philadelphia is known as the city of what..."
#   Processing query 347/568: "who is the singer of kal ho na ho..."
#   Processing query 348/568: "who is the minister of youth in namibia..."
#   Processing query 349/568: "what type of reaction occurs to form a dipeptide..."
#   Processing query 350/568: "the era of the great mughals began with the access..."
#   Processing query 351/568: "which financial statement involves all aspects of ..."
#   Processing query 352/568: "who plays bianca in that's so raven..."
#   Processing query 353/568: "what parts make up the peripheral nervous system..."
#   Processing query 354/568: "who were the two mathematicians that invented calc..."
#   Processing query 355/568: "where do red ear slider turtles lay eggs..."
#   Processing query 356/568: "when was the miraculous journey of edward tulane p..."
#   Processing query 357/568: "character in macbeth who is murdered and appears a..."
#   Processing query 358/568: "when did computer become widespread in homes and s..."
#   Processing query 359/568: "who has the most all star mvp awards..."
#   Processing query 360/568: "who laid the foundation of school of possibilism..."
#   Processing query 361/568: "who sang let me tell you about the birds and the b..."
#   Processing query 362/568: "how many us states are commonwealths and which sta..."
#   Processing query 363/568: "how many paintings of sunflowers did van gogh pain..."
#   Processing query 364/568: "who is the actress that plays penny on the big ban..."
#   Processing query 365/568: "who is known as the philippine queen of bossa nova..."
#   Processing query 366/568: "who sings only love can break your heart..."
#   Processing query 367/568: "what is alpha centauri's approximate distance from..."
#   Processing query 368/568: "who wins america's next top model cycle 20..."
#   Processing query 369/568: "who played david on the assassination of gianni ve..."
#   Processing query 370/568: "who was the mexican commander who surrendered to t..."
#   Processing query 371/568: "distance from one side of a bridge to the other cr..."
#   Processing query 372/568: "when do they put the rockefeller tree up..."
#   Processing query 373/568: "what do you say when you win bingo..."
#   Processing query 374/568: "where is fulda and what is its significance..."
#   Processing query 375/568: "towns on the border of texas and oklahoma..."
#   Processing query 376/568: "who killed missy in a bend in the road..."
#   Processing query 377/568: "which songs did liam write as you were..."
#   Processing query 378/568: "how many episodes are there in season six of nashv..."
#   Processing query 379/568: "why did ric flair go back to wcw..."
#   Processing query 380/568: "where does the phrase train of thought come from..."
#   Processing query 381/568: "where is iodine found in the periodic table..."
#   Processing query 382/568: "where is the oldest civilization known to man..."
#   Processing query 383/568: "when was the tower of london finished being built..."
#   Processing query 384/568: "when did the twenty one pilots hiatus start..."
#   Processing query 385/568: "when did cristiano ronaldo go to manchester united..."
#   Processing query 386/568: "who gets to race in the daytona clash..."
#   Processing query 387/568: "who said have you no sense of decency..."
#   Processing query 388/568: "who does claire from mcleods daughters end up with..."
#   Processing query 389/568: "who sings you are a magnet and i am steel..."
#   Processing query 390/568: "who wrote i can feel at home in this world anymore..."
#   Processing query 391/568: "where did the french immigrants settle in texas..."
#   Processing query 392/568: "how many seasons of the smurfs are there..."
#   Processing query 393/568: "when does sloan come into grey's anatomy..."
#   Processing query 394/568: "where did the battle of issus take place..."
#   Processing query 395/568: "what is the function of the pericardial sac..."
#   Processing query 396/568: "who helped them recapture mycenae once they were o..."
#   Processing query 397/568: "when was 13 reasons why released on netflix..."
#   Processing query 398/568: "who sings in walk hard the dewey cox story..."
#   Processing query 399/568: "in the song i drive your truck who is he talking a..."
#   Processing query 400/568: "who votes to elect a rajya sabha memmber..."
#   Processing query 401/568: "when did the eagles win the super bowl..."
#   Processing query 402/568: "how many rooms is there in buckingham palace..."
#   Processing query 403/568: "when was the last episode of vampire diaries aired..."
#   Processing query 404/568: "who donates a christmas tree to trafalgar square..."
#   Processing query 405/568: "who starred in the movie on golden pond..."
#   Processing query 406/568: "what is the rate limiting enzyme of kreb's cycle..."
#   Processing query 407/568: "when did the song holiday road come out..."
#   Processing query 408/568: "when does the mlb season start and finish..."
#   Processing query 409/568: "why is the indian ocean the warmest in the world..."
#   Processing query 410/568: "when did indoor toilets become common in america..."
#   Processing query 411/568: "who wrote were going on a bear hunt..."
#   Processing query 412/568: "when did the steel mills closed in youngstown ohio..."
#   Processing query 413/568: "who made the song falling in love with you..."
#   Processing query 414/568: "list of rights protected by the first amendment..."
#   Processing query 415/568: "in which country bikram sambhat the official calen..."
#   Processing query 416/568: "who sings the song i want to go outside in the rai..."
#   Processing query 417/568: "when did gimme gimme gimme start..."
#   Processing query 418/568: "who was the first english child born in north amer..."
#   Processing query 419/568: "who has the most wins on around the horn..."
#   Processing query 420/568: "where does a girl wear an engagement ring..."
#   Processing query 421/568: "when was to god be the glory written..."
#   Processing query 422/568: "when is season 7 race to the edge coming out..."
#   Processing query 423/568: "how many countries in the world have scouts..."
#   Processing query 424/568: "who's the guy in call me maybe..."
#   Processing query 425/568: "describe the various uses of forests to human bein..."
#   Processing query 426/568: "what grade was arnold from hey arnold in..."
#   Processing query 427/568: "what is money as a medium of exchange..."
#   Processing query 428/568: "when does season 7 game of thrones dvd release..."
#   Processing query 429/568: "third president of the united states of america..."
#   Processing query 430/568: "who abolished the monarchy and declared france a r..."
#   Processing query 431/568: "location of the ten commandments in the bible..."
#   Processing query 432/568: "roman god of the underworld also called orcus or p..."
#   Processing query 433/568: "cast of a nightmare on elm street 1984..."
#   Processing query 434/568: "what types of cells go through binary fission..."
#   Processing query 435/568: "when did vat change from 17.5 to 20..."
#   Processing query 436/568: "what is the location at the end of minority report..."
#   Processing query 437/568: "where does the sciatic nerve run in the foot..."
#   Processing query 438/568: "who used morse code in world war 2..."
#   Processing query 439/568: "who plays colin on young and the restless..."
#   Processing query 440/568: "when does the 2017 college football season end..."
#   Processing query 441/568: "how many games does a football team have to win to..."
#   Processing query 442/568: "who holds the record for most everest summits..."
#   Processing query 443/568: "who made the nuclear model of an atom..."
#   Processing query 444/568: "when does the shape of water book come out..."
#   Processing query 445/568: "where will the cricket world cup 2019 be held..."
#   Processing query 446/568: "who is the chief economic advisor of india..."
#   Processing query 447/568: "when did slave to the rhythm come out..."
#   Processing query 448/568: "who wins the final fight in real steel..."
#   Processing query 449/568: "when did the battle of bull run start..."
#   Processing query 450/568: "who won the most gold metals in olympics..."
#   Processing query 451/568: "where is nuclear energy used most in the world..."
#   Processing query 452/568: "who has won the most masters green jackets..."
#   Processing query 453/568: "what goes on the bottom of shepherd's pie..."
#   Processing query 454/568: "in texas how is the commissioner of insurance plac..."
#   Processing query 455/568: "where did the tradition of the pinata come from..."
#   Processing query 456/568: "when did the united states became a nation..."
#   Processing query 457/568: "when will notre dame played michigan state again..."
#   Processing query 458/568: "who sings love will keep us alive by the eagles..."
#   Processing query 459/568: "who has been chosen as the brand ambassador of the..."
#   Processing query 460/568: "where are the mitochondria located in the sperm..."
#   Processing query 461/568: "how many lines of symmetry are there in a equilate..."
#   Processing query 462/568: "when did the us not go to the olympics..."
#   Processing query 463/568: "where was the movie jeremiah johnson filmed at..."
#   Processing query 464/568: "who sang in the movie i walk the line..."
#   Processing query 465/568: "where does the electron transport chain pumps prot..."
#   Processing query 466/568: "when does isle of dogs come out in us..."
#   Processing query 467/568: "when does the new gotham season come out..."
#   Processing query 468/568: "who named all the animals in the world..."
#   Processing query 469/568: "how long do nhl players stay on waivers..."
#   Processing query 470/568: "when did the apple iphone se come out..."
#   Processing query 471/568: "where did the ashes from ash wednesday originate..."
#   Processing query 472/568: "who sings it's my party and i cry if i want to..."
#   Processing query 473/568: "nba record for most double doubles in a season..."
#   Processing query 474/568: "who sang on great gig in the sky..."
#   Processing query 475/568: "what college does everyone in gossip girl go to..."
#   Processing query 476/568: "internet based test of english as a foreign langua..."
#   Processing query 477/568: "who is responsible for introducing the principle o..."
#   Processing query 478/568: "who was the last nba player to get drafted out of ..."
#   Processing query 479/568: "fast and furious 7 red car abu dhabi..."
#   Processing query 480/568: "who is the guy that jumped from space..."
#   Processing query 481/568: "when did hollywood become the centre of the film i..."
#   Processing query 482/568: "what is the population of the tri-cities washingto..."
#   Processing query 483/568: "sri lanka belongs to which part of asia..."
#   Processing query 484/568: "who sings gimme some lovin in days of thunder..."
#   Processing query 485/568: "when did the eagles last play in a superbowl..."
#   Processing query 486/568: "who created the convention on the rights of the ch..."
#   Processing query 487/568: "who was the grandfather on the cosby show..."
#   Processing query 488/568: "where did the tea come from in the boston tea part..."
#   Processing query 489/568: "who did the whistling in the muppet movie..."
#   Processing query 490/568: "when did scotland last qualify for world cup..."
#   Processing query 491/568: "when was how deep is your love released..."
#   Processing query 492/568: "when is the world consumer right day celebrated..."
#   Processing query 493/568: "who plays hulk in the thor and avengers series of ..."
#   Processing query 494/568: "who wrote the song stop the world and let me off..."
#   Processing query 495/568: "who won the 7 man elimination chamber match..."
#   Processing query 496/568: "when did the royal mint move to wales..."
#   Processing query 497/568: "a synonym for the content component of communicati..."
#   Processing query 498/568: "where are more than half your bones located..."
#   Processing query 499/568: "who dies in the beginning of deathly hallows part ..."
#   Processing query 500/568: "who wrote the music phantom of the opera..."
#   Processing query 501/568: "what is cost of first class mail stamp..."
#   Processing query 502/568: "when did this season of american idol start..."
#   Processing query 503/568: "where did they film season 8 of the walking dead..."
#   Processing query 504/568: "what has been the origin of most classical dances ..."
#   Processing query 505/568: "for complaints of sudden chest pain patients shoul..."
#   Processing query 506/568: "what are the first and second major religions in f..."
#   Processing query 507/568: "what episode of pll does jenna get her sight back..."
#   Processing query 508/568: "how long do you have to serve in the israeli milit..."
#   Processing query 509/568: "who wrote the song to make you feel my love..."
#   Processing query 510/568: "what is the origin of the name marvin..."
#   Processing query 511/568: "who are the nbc olympic ice skating commentators..."
#   Processing query 512/568: "book series about the end of the world..."
#   Processing query 513/568: "who defeated the last remaining roman army in euro..."
#   Processing query 514/568: "when did the cubs won a world series..."
#   Processing query 515/568: "when does wentworth season 6 start in australia..."
#   Processing query 516/568: "what is the central idea of the poem the rime of a..."
#   Processing query 517/568: "when did the eagles win last super bowl..."
#   Processing query 518/568: "what is upstream project in oil and gas..."
#   Processing query 519/568: "when was the titanic started to be built..."
#   Processing query 520/568: "tools made from high-speed tool steel are generall..."
#   Processing query 521/568: "bacterial cell walls are made rigid by the presenc..."
#   Processing query 522/568: "what do you call a person who officiates a wedding..."
#   Processing query 523/568: "where is the light between two oceans filmed..."
#   Processing query 524/568: "when does season 8 of vampire diaries come out..."
#   Processing query 525/568: "who starred in the pirates of the caribbean..."
#   Processing query 526/568: "spyder from once upon a time in venice..."
#   Processing query 527/568: "who was the spanish civil war fought between..."
#   Processing query 528/568: "who came up with the theory of relativity..."
#   Processing query 529/568: "who played morticia in the addams family tv show..."
#   Processing query 530/568: "where is the lost dutchman's mine supposed to be l..."
#   Processing query 531/568: "when did the song push it come out..."
#   Processing query 532/568: "who plays the coach in old spice commercial..."
#   Processing query 533/568: "when was the nobel prize for literature first awar..."
#   Processing query 534/568: "the winner of the best actor award in the 64th nat..."
#   Processing query 535/568: "what were the two causes of the dust bowl..."
#   Processing query 536/568: "who plays the dad in drake and josh..."
#   Processing query 537/568: "what color is the golden gate bridge in san franci..."
#   Processing query 538/568: "who sings angel of the morning in deadpool..."
#   Processing query 539/568: "who did kenny rogers sing mary did you know with..."
#   Processing query 540/568: "what was the united states foreign policy after ww..."
#   Processing query 541/568: "when did world war 2 end in the pacific..."
#   Processing query 542/568: "what is the legal age for marriage in australia..."
#   Processing query 543/568: "what are the four requirements to establish crimin..."
#   Processing query 544/568: "where was a hologram for the king filmed..."
#   Processing query 545/568: "who inaugurated 'world teachers' day'..."
#   Processing query 546/568: "where are alkali metals located on the periodic ta..."
#   Processing query 547/568: "when did the newest macbook pro come out..."
#   Processing query 548/568: "what type of joint connects the incus with the mal..."
#   Processing query 549/568: "who did the original spirit in the sky..."
#   Processing query 550/568: "when was the last time a hurricane hit massachuset..."
#   Processing query 551/568: "who were the judges on dancing on ice 2014..."
#   Processing query 552/568: "where does some like it hot take place..."
#   Processing query 553/568: "when was the last time the seattle seahawks won th..."
#   Processing query 554/568: "when did goku first go super saiyan 4..."
#   Processing query 555/568: "when did the military plane crash in mississippi..."
#   Processing query 556/568: "where does a brisket come from on a cow..."
#   Processing query 557/568: "when will the la sagrada familia be finished..."
#   Processing query 558/568: "an open-source clone of unix created in the early ..."
#   Processing query 559/568: "what is the origin of the name robinson..."
#   Processing query 560/568: "german word for pleasure from someone else's pain..."
#   Processing query 561/568: "who scored the most points in a game nba history..."
#   Processing query 562/568: "when did the great plague of london start and end..."
#   Processing query 563/568: "when did the movie varsity blues come out..."
#   Processing query 564/568: "when do wood thrushes fly when they are migrating..."
#   Processing query 565/568: "who is singing in something just like this..."
#   Processing query 566/568: "who came up with the initial concept of protons an..."
#   Processing query 567/568: "when does the regular season start in mlb..."
#   Processing query 568/568: "who said some are born great in twelfth night..."
# Finished generating all answers in 42.36 seconds.
# Generating answers for 568 queries...
#   Processing query 1/568: "what type of fuel goes in a zippo..."
#   Processing query 2/568: "first jnanpith award was an autor of which languag..."
#   Processing query 3/568: "how many cracker barrels in the united states..."
#   Processing query 4/568: "who wrote the text for jeanie with the light brown..."
#   Processing query 5/568: "the basic steps of rational decision making includ..."
#   Processing query 6/568: "where does the bob and tom show broadcast from..."
#   Processing query 7/568: "when was i don't like mondays released..."
#   Processing query 8/568: "what does the pearl symbolize in the bible..."
#   Processing query 9/568: "when did under the cork tree come out..."
#   Processing query 10/568: "who sings the song let me love you..."
#   Processing query 11/568: "where was the first nhl hockey game played..."
#   Processing query 12/568: "who made delhi as capital for the first time..."
#   Processing query 13/568: "which domain of life are humans members of..."
#   Processing query 14/568: "when does the sa node begin electrical signaling..."
#   Processing query 15/568: "when is the last time the new york giants won the ..."
#   Processing query 16/568: "who won the battle of stirling bridge 1297..."
#   Processing query 17/568: "who is the present rajya sabha speaker of india..."
#   Processing query 18/568: "where is simple squamous epithelium found in the b..."
#   Processing query 19/568: "when was the last time mount ruapehu erupted..."
#   Processing query 20/568: "what proposition made the insurance commissioner a..."
#   Processing query 21/568: "who was the actor who played crocodile dundee..."
#   Processing query 22/568: "when's the last time philly won the superbowl..."
#   Processing query 23/568: "who is the character of santa claus based on..."
#   Processing query 24/568: "who wins the next iron chef super chefs..."
#   Processing query 25/568: "who sings i want to be a rockstar..."
#   Processing query 26/568: "where does the red wolf live in the world..."
#   Processing query 27/568: "what is the full scientific name for the e. coli b..."
#   Processing query 28/568: "who played alex cross in along came a spider..."
#   Processing query 29/568: "communities of similar organisms found in a partic..."
#   Processing query 30/568: "who wrote i'm in the mood for dancing..."
#   Processing query 31/568: "what is one element a topographic map shows..."
#   Processing query 32/568: "who started the tradition of coloring easter eggs..."
#   Processing query 33/568: "who were the first non native settlers in the us..."
#   Processing query 34/568: "when does season 6 of the next step start..."
#   Processing query 35/568: "abbreviated name of the highest peak in tasmania..."
#   Processing query 36/568: "who played mrs. trumbull on i love lucy..."
#   Processing query 37/568: "what is the order of the netflix marvel shows..."
#   Processing query 38/568: "what's the difference between salisbury steak and ..."
#   Processing query 39/568: "what are the 3 layers of the meninges..."
#   Processing query 40/568: "who did puss in boots grew up with..."
#   Processing query 41/568: "which type of hematoma is a result of torn bridgin..."
#   Processing query 42/568: "where does puerto rico's power come from..."
#   Processing query 43/568: "new movie of ajay devgan and sonakshi sinha..."
#   Processing query 44/568: "who sings i'll sleep when i'm dead..."
#   Processing query 45/568: "who owns the crown plaza hotel in chicago illinois..."
#   Processing query 46/568: "who is the original singer of i write sins not tra..."
#   Processing query 47/568: "name of black man in to kill a mockingbird..."
#   Processing query 48/568: "where did chocolate originate the americas spain a..."
#   Processing query 49/568: "of which country is sofia the capital city..."
#   Processing query 50/568: "who played hyde in league of extraordinary gentlem..."
#   Processing query 51/568: "where is dancing on ice filmed this year..."
#   Processing query 52/568: "when did korn's follow the leader come out..."
#   Processing query 53/568: "when did new york stop using the electric chair..."
#   Processing query 54/568: "where is the world cup being held 2018..."
#   Processing query 55/568: "how many dominoes do you need for mexican train..."
#   Processing query 56/568: "where will be the next olympics be held..."
#   Processing query 57/568: "where is wind power used most in the united states..."
#   Processing query 58/568: "who played john connor in the original terminator..."
#   Processing query 59/568: "jawaharlal nehru centre for advanced scientific re..."
#   Processing query 60/568: "where is arachidonic acid found in the body..."
#   Processing query 61/568: "what is the meaning of the name habib..."
#   Processing query 62/568: "who plays the dragon queen from game of thrones..."
#   Processing query 63/568: "who played mr. kincaid on the partridge family..."
#   Processing query 64/568: "what are the three fifty shades of grey books..."
#   Processing query 65/568: "how many pennsylvania house of representatives are..."
#   Processing query 66/568: "who designed the first toy released by nintendo..."
#   Processing query 67/568: "when did the nfl start playing in london..."
#   Processing query 68/568: "what is the meaning of the word autumn..."
#   Processing query 69/568: "when did day light savings start in the us..."
#   Processing query 70/568: "number of degree of freedom for plane mechanism..."
#   Processing query 71/568: "who missed the plane the day the music died..."
#   Processing query 72/568: "when did the usa join world war one..."
#   Processing query 73/568: "who sings don't take your guns to town..."
#   Processing query 74/568: "who designed the traffic circle in long beach ca..."
#   Processing query 75/568: "the fellowship of the ring director's cut length..."
#   Processing query 76/568: "when does the new season of are you the one come o..."
#   Processing query 77/568: "who received the most (but not a majority of) elec..."
#   Processing query 78/568: "under the federal unemployment tax act which party..."
#   Processing query 79/568: "who is the most selling music artist of all time..."
#   Processing query 80/568: "when did the united states host the world cup..."
#   Processing query 81/568: "the secret of crickley hall how many episodes..."
#   Processing query 82/568: "who sang what i like about you originally..."
#   Processing query 83/568: "who played gareth in four weddings and a funeral..."
#   Processing query 84/568: "who is the actor that plays saul on grace and fran..."
#   Processing query 85/568: "in which city are the wimbledon game held..."
#   Processing query 86/568: "why does cooling water run through the condenser..."
#   Processing query 87/568: "what was hawaii's primary export to the united sta..."
#   Processing query 88/568: "who sings i will go down with this ship..."
#   Processing query 89/568: "where does the last name hidalgo come from..."
#   Processing query 90/568: "when was the canadian pacific railway started and ..."
#   Processing query 91/568: "who built pedestrian bridge at florida internation..."
#   Processing query 92/568: "where does the name de la rosa come from..."
#   Processing query 93/568: "most home runs by 2 teammates in a season..."
#   Processing query 94/568: "who owned the colts when they left baltimore..."
#   Processing query 95/568: "where is the battle of britain flight based..."
#   Processing query 96/568: "when is i can only imagine coming out..."
#   Processing query 97/568: "the plane of earth's orbit is called the..."
#   Processing query 98/568: "who sang the song brother let me be your shelter..."
#   Processing query 99/568: "what percent of the us population controls the wea..."
#   Processing query 100/568: "what languages are spoken in india the most..."
#   Processing query 101/568: "who plays harry's mom in harry potter..."
#   Processing query 102/568: "where was the u.s.s maine when it exploded in 1898..."
#   Processing query 103/568: "in the honour of which god is anant chaturdashi ce..."
#   Processing query 104/568: "five tools of security management to overcome comp..."
#   Processing query 105/568: "who sang what are we doing in love..."
#   Processing query 106/568: "what is the snow on mars made of..."
#   Processing query 107/568: "who sings the theme song for living single..."
#   Processing query 108/568: "which foreign currency option is the​ right but no..."
#   Processing query 109/568: "how many house of representative do we have in nig..."
#   Processing query 110/568: "who is the supreme court judge was a former chief ..."
#   Processing query 111/568: "when was the last time the los angeles lakers won ..."
#   Processing query 112/568: "what disney cartoon character's middle name is fau..."
#   Processing query 113/568: "where can carbon be found in the biosphere..."
#   Processing query 114/568: "other than water what else has hydrogen bonds..."
#   Processing query 115/568: "when boy meets girl waiting for a star to fall..."
#   Processing query 116/568: "who formed and first came to the colony of marylan..."
#   Processing query 117/568: "who has played in the most masters tournaments..."
#   Processing query 118/568: "last team to win fa cup outside top flight..."
#   Processing query 119/568: "who played anne in anne with an e..."
#   Processing query 120/568: "theme of the song roar by katy perry..."
#   Processing query 121/568: "who picks the players in the nfl draft..."
#   Processing query 122/568: "where was the 2015 rugby union world cup held..."
#   Processing query 123/568: "who got the first nobel prize in physics..."
#   Processing query 124/568: "when is the last time the philadelphia won the sup..."
#   Processing query 125/568: "swan lake the sleeping beauty and the nutcracker a..."
#   Processing query 126/568: "who designed the garden city of new earswick..."
#   Processing query 127/568: "what is the first step in the evolution of the eye..."
#   Processing query 128/568: "what is the main mineral in lithium batteries..."
#   Processing query 129/568: "in which sea pearl is found in india..."
#   Processing query 130/568: "what is the meaning of the name sinead..."
#   Processing query 131/568: "who will take the throne after the queen dies..."
#   Processing query 132/568: "who is the girl in green day 21 guns..."
#   Processing query 133/568: "name the process of fusion of an egg with a sperm..."
#   Processing query 134/568: "when was the first documented case of tool mark id..."
#   Processing query 135/568: "who sang rip it up and start again..."
#   Processing query 136/568: "whens the last time the patriots played the eagles..."
#   Processing query 137/568: "who starred in the movie summer of 42..."
#   Processing query 138/568: "which site of an enzyme is called allosteric site..."
#   Processing query 139/568: "when did the name of bombay change to mumbai..."
#   Processing query 140/568: "how old is the actress who plays phyllis on y&r..."
#   Processing query 141/568: "what is the official symbol of the carnival of que..."
#   Processing query 142/568: "where is the country music hall of fame located..."
#   Processing query 143/568: "who has won india's next super star..."
#   Processing query 144/568: "what was the first video game for nintendo..."
#   Processing query 145/568: "when did the the regulatory reform (fire safety) o..."
#   Processing query 146/568: "who want to be a millionaire calls his dad..."
#   Processing query 147/568: "two examples where low voltage transformers are us..."
#   Processing query 148/568: "what causes cracked skin at the corners of your mo..."
#   Processing query 149/568: "who had the longest tenure as moderator on meet th..."
#   Processing query 150/568: "industrial city in germany on the rhine herne cana..."
#   Processing query 151/568: "who sings the song it ain't me..."
#   Processing query 152/568: "where does the optic nerve cross the midline ​..."
#   Processing query 153/568: "who did the central powers defeat on the eastern f..."
#   Processing query 154/568: "who was the captain of the mayflower when it took ..."
#   Processing query 155/568: "when does the cannes film festival take place..."
#   Processing query 156/568: "where was held the first session of muslim league..."
#   Processing query 157/568: "what is the largest magnitude earthquake that has ..."
#   Processing query 158/568: "when does the champions league quarter finals star..."
#   Processing query 159/568: "when did the term sustainability start to be used..."
#   Processing query 160/568: "fast & furious 8 release date in india..."
#   Processing query 161/568: "when does the movie jeepers creepers come out..."
#   Processing query 162/568: "the joint between a coxal bone of the pelvis and t..."
#   Processing query 163/568: "who played cosette in les miserables on broadway..."
#   Processing query 164/568: "whats the difference between tomato paste and toma..."
#   Processing query 165/568: "what type of plate boundary is associated with ice..."
#   Processing query 166/568: "who plays jimmy's mom in 8 mile..."
#   Processing query 167/568: "actress who plays brad pitts wife in war machine..."
#   Processing query 168/568: "who is the book of galatians written to..."
#   Processing query 169/568: "what is the name of the hyena in lion king..."
#   Processing query 170/568: "when does the new death of superman come out..."
#   Processing query 171/568: "when was a series of unfortunate events published..."
#   Processing query 172/568: "what nfl player has the most nfl rings..."
#   Processing query 173/568: "when did canada get rid of the death penalty..."
#   Processing query 174/568: "when did we first put a rover on mars..."
#   Processing query 175/568: "who plays the mouse in alice in wonderland..."
#   Processing query 176/568: "rain sleet or snow that contains a high concentrat..."
#   Processing query 177/568: "who plays jack skellington in nightmare before chr..."
#   Processing query 178/568: "make it or break it who goes to the olympics..."
#   Processing query 179/568: "where was the movie i am number 4 filmed..."
#   Processing query 180/568: "who is the current defence against the dark arts t..."
#   Processing query 181/568: "what does g stand for in ncis los angeles..."
#   Processing query 182/568: "who sang i'm gonna run away from you..."
#   Processing query 183/568: "what are the two extracellular fluid compartments ..."
#   Processing query 184/568: "who wrote shes always a woman to me..."
#   Processing query 185/568: "how many times have real madrid won the champions ..."
#   Processing query 186/568: "who invented the glasses that give sight to the bl..."
#   Processing query 187/568: "who are the permanent member of un security counci..."
# ...
#   Processing query 370/568: "who was the mexican commander who surrendered to t..."
#   Processing query 371/568: "distance from one side of a bridge to the other cr..."
#   Processing query 372/568: "when do they put the rockefeller tree up..."
#   Processing query 373/568: "what do you say when you win bingo..."
#   Processing query 374/568: "where is fulda and what is its significance..."
#   Processing query 375/568: "towns on the border of texas and oklahoma..."
#   Processing query 376/568: "who killed missy in a bend in the road..."
#   Processing query 377/568: "which songs did liam write as you were..."
#   Processing query 378/568: "how many episodes are there in season six of nashv..."
#   Processing query 379/568: "why did ric flair go back to wcw..."
#   Processing query 380/568: "where does the phrase train of thought come from..."
#   Processing query 381/568: "where is iodine found in the periodic table..."
#   Processing query 382/568: "where is the oldest civilization known to man..."
#   Processing query 383/568: "when was the tower of london finished being built..."
#   Processing query 384/568: "when did the twenty one pilots hiatus start..."
#   Processing query 385/568: "when did cristiano ronaldo go to manchester united..."
#   Processing query 386/568: "who gets to race in the daytona clash..."
#   Processing query 387/568: "who said have you no sense of decency..."
#   Processing query 388/568: "who does claire from mcleods daughters end up with..."
#   Processing query 389/568: "who sings you are a magnet and i am steel..."
#   Processing query 390/568: "who wrote i can feel at home in this world anymore..."
#   Processing query 391/568: "where did the french immigrants settle in texas..."
#   Processing query 392/568: "how many seasons of the smurfs are there..."
#   Processing query 393/568: "when does sloan come into grey's anatomy..."
#   Processing query 394/568: "where did the battle of issus take place..."
#   Processing query 395/568: "what is the function of the pericardial sac..."
#   Processing query 396/568: "who helped them recapture mycenae once they were o..."
#   Processing query 397/568: "when was 13 reasons why released on netflix..."
#   Processing query 398/568: "who sings in walk hard the dewey cox story..."
#   Processing query 399/568: "in the song i drive your truck who is he talking a..."
#   Processing query 400/568: "who votes to elect a rajya sabha memmber..."
#   Processing query 401/568: "when did the eagles win the super bowl..."
#   Processing query 402/568: "how many rooms is there in buckingham palace..."
#   Processing query 403/568: "when was the last episode of vampire diaries aired..."
#   Processing query 404/568: "who donates a christmas tree to trafalgar square..."
#   Processing query 405/568: "who starred in the movie on golden pond..."
#   Processing query 406/568: "what is the rate limiting enzyme of kreb's cycle..."
#   Processing query 407/568: "when did the song holiday road come out..."
#   Processing query 408/568: "when does the mlb season start and finish..."
#   Processing query 409/568: "why is the indian ocean the warmest in the world..."
#   Processing query 410/568: "when did indoor toilets become common in america..."
#   Processing query 411/568: "who wrote were going on a bear hunt..."
#   Processing query 412/568: "when did the steel mills closed in youngstown ohio..."
#   Processing query 413/568: "who made the song falling in love with you..."
#   Processing query 414/568: "list of rights protected by the first amendment..."
#   Processing query 415/568: "in which country bikram sambhat the official calen..."
#   Processing query 416/568: "who sings the song i want to go outside in the rai..."
#   Processing query 417/568: "when did gimme gimme gimme start..."
#   Processing query 418/568: "who was the first english child born in north amer..."
#   Processing query 419/568: "who has the most wins on around the horn..."
#   Processing query 420/568: "where does a girl wear an engagement ring..."
#   Processing query 421/568: "when was to god be the glory written..."
#   Processing query 422/568: "when is season 7 race to the edge coming out..."
#   Processing query 423/568: "how many countries in the world have scouts..."
#   Processing query 424/568: "who's the guy in call me maybe..."
#   Processing query 425/568: "describe the various uses of forests to human bein..."
#   Processing query 426/568: "what grade was arnold from hey arnold in..."
#   Processing query 427/568: "what is money as a medium of exchange..."
#   Processing query 428/568: "when does season 7 game of thrones dvd release..."
#   Processing query 429/568: "third president of the united states of america..."
#   Processing query 430/568: "who abolished the monarchy and declared france a r..."
#   Processing query 431/568: "location of the ten commandments in the bible..."
#   Processing query 432/568: "roman god of the underworld also called orcus or p..."
#   Processing query 433/568: "cast of a nightmare on elm street 1984..."
#   Processing query 434/568: "what types of cells go through binary fission..."
#   Processing query 435/568: "when did vat change from 17.5 to 20..."
#   Processing query 436/568: "what is the location at the end of minority report..."
#   Processing query 437/568: "where does the sciatic nerve run in the foot..."
#   Processing query 438/568: "who used morse code in world war 2..."
#   Processing query 439/568: "who plays colin on young and the restless..."
#   Processing query 440/568: "when does the 2017 college football season end..."
#   Processing query 441/568: "how many games does a football team have to win to..."
#   Processing query 442/568: "who holds the record for most everest summits..."
#   Processing query 443/568: "who made the nuclear model of an atom..."
#   Processing query 444/568: "when does the shape of water book come out..."
#   Processing query 445/568: "where will the cricket world cup 2019 be held..."
#   Processing query 446/568: "who is the chief economic advisor of india..."
#   Processing query 447/568: "when did slave to the rhythm come out..."
#   Processing query 448/568: "who wins the final fight in real steel..."
#   Processing query 449/568: "when did the battle of bull run start..."
#   Processing query 450/568: "who won the most gold metals in olympics..."
#   Processing query 451/568: "where is nuclear energy used most in the world..."
#   Processing query 452/568: "who has won the most masters green jackets..."
#   Processing query 453/568: "what goes on the bottom of shepherd's pie..."
#   Processing query 454/568: "in texas how is the commissioner of insurance plac..."
#   Processing query 455/568: "where did the tradition of the pinata come from..."
#   Processing query 456/568: "when did the united states became a nation..."
#   Processing query 457/568: "when will notre dame played michigan state again..."
#   Processing query 458/568: "who sings love will keep us alive by the eagles..."
#   Processing query 459/568: "who has been chosen as the brand ambassador of the..."
#   Processing query 460/568: "where are the mitochondria located in the sperm..."
#   Processing query 461/568: "how many lines of symmetry are there in a equilate..."
#   Processing query 462/568: "when did the us not go to the olympics..."
#   Processing query 463/568: "where was the movie jeremiah johnson filmed at..."
#   Processing query 464/568: "who sang in the movie i walk the line..."
#   Processing query 465/568: "where does the electron transport chain pumps prot..."
#   Processing query 466/568: "when does isle of dogs come out in us..."
#   Processing query 467/568: "when does the new gotham season come out..."
#   Processing query 468/568: "who named all the animals in the world..."
#   Processing query 469/568: "how long do nhl players stay on waivers..."
#   Processing query 470/568: "when did the apple iphone se come out..."
#   Processing query 471/568: "where did the ashes from ash wednesday originate..."
#   Processing query 472/568: "who sings it's my party and i cry if i want to..."
#   Processing query 473/568: "nba record for most double doubles in a season..."
#   Processing query 474/568: "who sang on great gig in the sky..."
#   Processing query 475/568: "what college does everyone in gossip girl go to..."
#   Processing query 476/568: "internet based test of english as a foreign langua..."
#   Processing query 477/568: "who is responsible for introducing the principle o..."
#   Processing query 478/568: "who was the last nba player to get drafted out of ..."
#   Processing query 479/568: "fast and furious 7 red car abu dhabi..."
#   Processing query 480/568: "who is the guy that jumped from space..."
#   Processing query 481/568: "when did hollywood become the centre of the film i..."
#   Processing query 482/568: "what is the population of the tri-cities washingto..."
#   Processing query 483/568: "sri lanka belongs to which part of asia..."
#   Processing query 484/568: "who sings gimme some lovin in days of thunder..."
#   Processing query 485/568: "when did the eagles last play in a superbowl..."
#   Processing query 486/568: "who created the convention on the rights of the ch..."
#   Processing query 487/568: "who was the grandfather on the cosby show..."
#   Processing query 488/568: "where did the tea come from in the boston tea part..."
#   Processing query 489/568: "who did the whistling in the muppet movie..."
#   Processing query 490/568: "when did scotland last qualify for world cup..."
#   Processing query 491/568: "when was how deep is your love released..."
#   Processing query 492/568: "when is the world consumer right day celebrated..."
#   Processing query 493/568: "who plays hulk in the thor and avengers series of ..."
#   Processing query 494/568: "who wrote the song stop the world and let me off..."
#   Processing query 495/568: "who won the 7 man elimination chamber match..."
#   Processing query 496/568: "when did the royal mint move to wales..."
#   Processing query 497/568: "a synonym for the content component of communicati..."
#   Processing query 498/568: "where are more than half your bones located..."
#   Processing query 499/568: "who dies in the beginning of deathly hallows part ..."
#   Processing query 500/568: "who wrote the music phantom of the opera..."
#   Processing query 501/568: "what is cost of first class mail stamp..."
#   Processing query 502/568: "when did this season of american idol start..."
#   Processing query 503/568: "where did they film season 8 of the walking dead..."
#   Processing query 504/568: "what has been the origin of most classical dances ..."
#   Processing query 505/568: "for complaints of sudden chest pain patients shoul..."
#   Processing query 506/568: "what are the first and second major religions in f..."
#   Processing query 507/568: "what episode of pll does jenna get her sight back..."
#   Processing query 508/568: "how long do you have to serve in the israeli milit..."
#   Processing query 509/568: "who wrote the song to make you feel my love..."
#   Processing query 510/568: "what is the origin of the name marvin..."
#   Processing query 511/568: "who are the nbc olympic ice skating commentators..."
#   Processing query 512/568: "book series about the end of the world..."
#   Processing query 513/568: "who defeated the last remaining roman army in euro..."
#   Processing query 514/568: "when did the cubs won a world series..."
#   Processing query 515/568: "when does wentworth season 6 start in australia..."
#   Processing query 516/568: "what is the central idea of the poem the rime of a..."
#   Processing query 517/568: "when did the eagles win last super bowl..."
#   Processing query 518/568: "what is upstream project in oil and gas..."
#   Processing query 519/568: "when was the titanic started to be built..."
#   Processing query 520/568: "tools made from high-speed tool steel are generall..."
#   Processing query 521/568: "bacterial cell walls are made rigid by the presenc..."
#   Processing query 522/568: "what do you call a person who officiates a wedding..."
#   Processing query 523/568: "where is the light between two oceans filmed..."
#   Processing query 524/568: "when does season 8 of vampire diaries come out..."
#   Processing query 525/568: "who starred in the pirates of the caribbean..."
#   Processing query 526/568: "spyder from once upon a time in venice..."
#   Processing query 527/568: "who was the spanish civil war fought between..."
#   Processing query 528/568: "who came up with the theory of relativity..."
#   Processing query 529/568: "who played morticia in the addams family tv show..."
#   Processing query 530/568: "where is the lost dutchman's mine supposed to be l..."
#   Processing query 531/568: "when did the song push it come out..."
#   Processing query 532/568: "who plays the coach in old spice commercial..."
#   Processing query 533/568: "when was the nobel prize for literature first awar..."
#   Processing query 534/568: "the winner of the best actor award in the 64th nat..."
#   Processing query 535/568: "what were the two causes of the dust bowl..."
#   Processing query 536/568: "who plays the dad in drake and josh..."
#   Processing query 537/568: "what color is the golden gate bridge in san franci..."
#   Processing query 538/568: "who sings angel of the morning in deadpool..."
#   Processing query 539/568: "who did kenny rogers sing mary did you know with..."
#   Processing query 540/568: "what was the united states foreign policy after ww..."
#   Processing query 541/568: "when did world war 2 end in the pacific..."
#   Processing query 542/568: "what is the legal age for marriage in australia..."
#   Processing query 543/568: "what are the four requirements to establish crimin..."
#   Processing query 544/568: "where was a hologram for the king filmed..."
#   Processing query 545/568: "who inaugurated 'world teachers' day'..."
#   Processing query 546/568: "where are alkali metals located on the periodic ta..."
#   Processing query 547/568: "when did the newest macbook pro come out..."
#   Processing query 548/568: "what type of joint connects the incus with the mal..."
#   Processing query 549/568: "who did the original spirit in the sky..."
#   Processing query 550/568: "when was the last time a hurricane hit massachuset..."
#   Processing query 551/568: "who were the judges on dancing on ice 2014..."
#   Processing query 552/568: "where does some like it hot take place..."
#   Processing query 553/568: "when was the last time the seattle seahawks won th..."
#   Processing query 554/568: "when did goku first go super saiyan 4..."
#   Processing query 555/568: "when did the military plane crash in mississippi..."
#   Processing query 556/568: "where does a brisket come from on a cow..."
#   Processing query 557/568: "when will the la sagrada familia be finished..."
#   Processing query 558/568: "an open-source clone of unix created in the early ..."
#   Processing query 559/568: "what is the origin of the name robinson..."
#   Processing query 560/568: "german word for pleasure from someone else's pain..."
#   Processing query 561/568: "who scored the most points in a game nba history..."
#   Processing query 562/568: "when did the great plague of london start and end..."
#   Processing query 563/568: "when did the movie varsity blues come out..."
#   Processing query 564/568: "when do wood thrushes fly when they are migrating..."
#   Processing query 565/568: "who is singing in something just like this..."
#   Processing query 566/568: "who came up with the initial concept of protons an..."
#   Processing query 567/568: "when does the regular season start in mlb..."
#   Processing query 568/568: "who said some are born great in twelfth night..."
# Finished generating all answers in 473.66 seconds.
# Saved end-to-end scores in logs/end_to_end_BM25_K40.json.
#
# For metric P_40 (BM25, K=40):
#   Spearman correlation: 0.234 (p=0.000)
#   Kendall correlation:   0.232 (p=0.000)
#
# For metric success_40 (BM25, K=40):
#   Spearman correlation: 0.234 (p=0.000)
#   Kendall correlation:   0.234 (p=0.000)
# Error for BM25 with K=40: 'BM25'
#
# --- Final correlation summary ---
# {'BM25': {}}
